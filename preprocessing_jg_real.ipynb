# %%
import cv2
import numpy as np
import os
import zipfile

# Paths provided by you
input_dir = 'Citra Real/Jajar Genjang'
output_dir = 'PREPROCESSING/Jajar Genjang Segmented'

# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)

# Define the range of purple color in HSV
lower_purple = np.array([50, 50, 50])
upper_purple = np.array([70, 255, 255])

# Process each image in the input directory
for filename in os.listdir(input_dir):
    if filename.endswith(('.png', '.jpg', '.jpeg')):
        # Load the image
        image_path = os.path.join(input_dir, filename)
        image = cv2.imread(image_path)
        
        # Convert the image to HSV color space
        hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
        
        # Create a mask for the purple color
        mask = cv2.inRange(hsv, lower_purple, upper_purple)
        
        # Apply the mask to get the segmented image
        segmented_image = cv2.bitwise_and(image, image, mask=mask)
        
        # Save the segmented image
        output_path = os.path.join(output_dir, filename)
        cv2.imwrite(output_path, segmented_image)
        
        print(f'Segmented image saved: {output_path}')
# Out:
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG1.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG10.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG11.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG12.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG13.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG14.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG15.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG16.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG17.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG18.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG19.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG2.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG20.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG21.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG22.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG23.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG24.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG25.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG26.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG27.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG28.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG29.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG3.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG30.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG31.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG32.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG33.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG34.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG35.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG36.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG37.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG38.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG39.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG4.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG40.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG41.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG42.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG43.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG44.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG45.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG46.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG47.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG48.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG49.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG5.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG50.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG51.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG52.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG53.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG54.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG55.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG56.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG57.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG58.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG59.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG6.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG60.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG7.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG8.jpg
# Segmented image saved: PREPROCESSING/Jajar Genjang Segmented\JG9.jpg

# %%
import cv2
import os

# Directory paths
segmented_dir = 'PREPROCESSING/Jajar Genjang Segmented'
grayscale_output_dir = 'PREPROCESSING/Jajar Genjang Grayscale'

# Ensure the output directory exists
os.makedirs(grayscale_output_dir, exist_ok=True)

# Process each image in the segmented directory
for filename in os.listdir(segmented_dir):
    if filename.endswith(('.png', '.jpg', '.jpeg')):
        # Load the segmented image
        segmented_image_path = os.path.join(segmented_dir, filename)
        segmented_image = cv2.imread(segmented_image_path)
        
        # Convert the image to grayscale
        grayscale_image = cv2.cvtColor(segmented_image, cv2.COLOR_BGR2GRAY)
        
        # Save the grayscale image
        grayscale_image_path = os.path.join(grayscale_output_dir, filename)
        cv2.imwrite(grayscale_image_path, grayscale_image)
        
        print(f'Grayscale image saved: {grayscale_image_path}')
# Out:
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG1.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG10.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG11.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG12.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG13.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG14.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG15.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG16.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG17.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG18.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG19.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG2.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG20.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG21.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG22.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG23.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG24.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG25.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG26.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG27.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG28.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG29.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG3.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG30.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG31.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG32.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG33.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG34.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG35.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG36.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG37.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG38.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG39.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG4.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG40.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG41.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG42.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG43.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG44.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG45.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG46.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG47.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG48.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG49.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG5.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG50.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG51.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG52.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG53.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG54.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG55.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG56.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG57.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG58.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG59.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG6.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG60.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG7.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG8.jpg
# Grayscale image saved: PREPROCESSING/Jajar Genjang Grayscale\JG9.jpg

# %%
import cv2
import os

# Directory paths
input_dir = 'PREPROCESSING/Jajar Genjang Grayscale'
output_dir = 'PREPROCESSING/Jajar Genjang Binary'

# Memastikan direktori output ada
os.makedirs(output_dir, exist_ok=True)

# Mendapatkan daftar file di direktori input
file_list = os.listdir(input_dir)

# Memproses setiap file gambar
for file_name in file_list:
    # Membaca gambar
    input_path = os.path.join(input_dir, file_name)
    image = cv2.imread(input_path, cv2.IMREAD_GRAYSCALE)  # Membaca langsung sebagai grayscale

    # Memeriksa apakah gambar berhasil dibaca
    if image is None:
        print(f"Failed to read {file_name}")
        continue

    # Mengonversi gambar grayscale menjadi citra biner menggunakan thresholding dengan tipe binary
    _, binary_image = cv2.threshold(image, 10, 255, cv2.THRESH_BINARY)
    
    # Menghilangkan noise menggunakan median blur
    denoised_image = cv2.medianBlur(binary_image, 5)  # Kernel size 5

    # Menyimpan gambar biner di direktori output
    output_path = os.path.join(output_dir, file_name)
    cv2.imwrite(output_path, denoised_image)

    print(f"Processed and saved: {file_name}")

print("Processing complete.")
# Out:
# Processed and saved: JG1.jpg
# Processed and saved: JG10.jpg
# Processed and saved: JG11.jpg
# Processed and saved: JG12.jpg
# Processed and saved: JG13.jpg
# Processed and saved: JG14.jpg
# Processed and saved: JG15.jpg
# Processed and saved: JG16.jpg
# Processed and saved: JG17.jpg
# Processed and saved: JG18.jpg
# Processed and saved: JG19.jpg
# Processed and saved: JG2.jpg
# Processed and saved: JG20.jpg
# Processed and saved: JG21.jpg
# Processed and saved: JG22.jpg
# Processed and saved: JG23.jpg
# Processed and saved: JG24.jpg
# Processed and saved: JG25.jpg
# Processed and saved: JG26.jpg
# Processed and saved: JG27.jpg
# Processed and saved: JG28.jpg
# Processed and saved: JG29.jpg
# Processed and saved: JG3.jpg
# Processed and saved: JG30.jpg
# Processed and saved: JG31.jpg
# Processed and saved: JG32.jpg
# Processed and saved: JG33.jpg
# Processed and saved: JG34.jpg
# Processed and saved: JG35.jpg
# Processed and saved: JG36.jpg
# Processed and saved: JG37.jpg
# Processed and saved: JG38.jpg
# Processed and saved: JG39.jpg
# Processed and saved: JG4.jpg
# Processed and saved: JG40.jpg
# Processed and saved: JG41.jpg
# Processed and saved: JG42.jpg
# Processed and saved: JG43.jpg
# Processed and saved: JG44.jpg
# Processed and saved: JG45.jpg
# Processed and saved: JG46.jpg
# Processed and saved: JG47.jpg
# Processed and saved: JG48.jpg
# Processed and saved: JG49.jpg
# Processed and saved: JG5.jpg
# Processed and saved: JG50.jpg
# Processed and saved: JG51.jpg
# Processed and saved: JG52.jpg
# Processed and saved: JG53.jpg
# Processed and saved: JG54.jpg
# Processed and saved: JG55.jpg
# Processed and saved: JG56.jpg
# Processed and saved: JG57.jpg
# Processed and saved: JG58.jpg
# Processed and saved: JG59.jpg
# Processed and saved: JG6.jpg
# Processed and saved: JG60.jpg
# Processed and saved: JG7.jpg
# Processed and saved: JG8.jpg
# Processed and saved: JG9.jpg
# Processing complete.

# %%
import cv2
import numpy as np
import os

# Path direktori
input_dir = 'PREPROCESSING/Jajar Genjang Binary'
output_dir = 'PREPROCESSING/Jajar Genjang Filled'

# Memastikan direktori output ada
os.makedirs(output_dir, exist_ok=True)

# Mendapatkan daftar file di direktori input
file_list = os.listdir(input_dir)

# Mendefinisikan elemen struktural (kernel) untuk operasi morfologi
kernel = np.ones((5, 5), np.uint8)  # Kernel ukuran 5x5, dapat disesuaikan

# Memproses setiap file gambar
for file_name in file_list:
    # Membaca gambar
    input_path = os.path.join(input_dir, file_name)
    image = cv2.imread(input_path, cv2.IMREAD_GRAYSCALE)

    # Memeriksa apakah gambar berhasil dibaca
    if image is None:
        print(f"Gagal membaca {file_name}")
        continue

    # Melakukan iterasi proses erosi dan dilasi sebanyak 30 kali
    for _ in range(30):
        # Erosi
        eroded_image = cv2.erode(image, kernel, iterations=100)
        # Dilasi
        image = cv2.dilate(eroded_image, kernel, iterations=100)

    # Menyimpan gambar hasil erosi dan dilasi di direktori output
    output_path = os.path.join(output_dir, file_name)
    cv2.imwrite(output_path, image)

    print(f"Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: {file_name}")

print("Proses erosi dan dilasi selesai untuk semua gambar.")
# Out:
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG1.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG10.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG11.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG12.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG13.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG14.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG15.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG16.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG17.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG18.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG19.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG2.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG20.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG21.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG22.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG23.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG24.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG25.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG26.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG27.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG28.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG29.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG3.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG30.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG31.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG32.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG33.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG34.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG35.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG36.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG37.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG38.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG39.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG4.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG40.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG41.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG42.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG43.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG44.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG45.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG46.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG47.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG48.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG49.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG5.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG50.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG51.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG52.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG53.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG54.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG55.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG56.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG57.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG58.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG59.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG6.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG60.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG7.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG8.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: JG9.jpg
# Proses erosi dan dilasi selesai untuk semua gambar.

# %%
import cv2
import os
import numpy as np

# Path direktori
input_dir = 'PREPROCESSING/Jajar Genjang Filled'
output_dir = 'PREPROCESSING/Jajar Genjang Opening'

# Memastikan direktori output ada
os.makedirs(output_dir, exist_ok=True)

# Mendapatkan daftar file di direktori input
file_list = os.listdir(input_dir)

# Mendefinisikan elemen struktural (kernel) untuk operasi morfologi
kernel = np.ones((5, 5), np.uint8)  # Kernel ukuran 5x5, dapat disesuaikan

# Memproses setiap file gambar
for file_name in file_list:
    # Membaca gambar
    input_path = os.path.join(input_dir, file_name)
    image = cv2.imread(input_path, cv2.IMREAD_GRAYSCALE)

    # Memeriksa apakah gambar berhasil dibaca
    if image is None:
        print(f"Gagal membaca {file_name}")
        continue

    # Melakukan operasi opening (erosi diikuti dilasi)
    opened_image = cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)

    # Menyimpan gambar hasil opening di direktori output
    output_path = os.path.join(output_dir, file_name)
    cv2.imwrite(output_path, opened_image)

    print(f"Proses opening selesai dan gambar disimpan: {file_name}")

print("Proses opening selesai untuk semua gambar.")
# Out:
# Proses opening selesai dan gambar disimpan: JG1.jpg
# Proses opening selesai dan gambar disimpan: JG10.jpg
# Proses opening selesai dan gambar disimpan: JG11.jpg
# Proses opening selesai dan gambar disimpan: JG12.jpg
# Proses opening selesai dan gambar disimpan: JG13.jpg
# Proses opening selesai dan gambar disimpan: JG14.jpg
# Proses opening selesai dan gambar disimpan: JG15.jpg
# Proses opening selesai dan gambar disimpan: JG16.jpg
# Proses opening selesai dan gambar disimpan: JG17.jpg
# Proses opening selesai dan gambar disimpan: JG18.jpg
# Proses opening selesai dan gambar disimpan: JG19.jpg
# Proses opening selesai dan gambar disimpan: JG2.jpg
# Proses opening selesai dan gambar disimpan: JG20.jpg
# Proses opening selesai dan gambar disimpan: JG21.jpg
# Proses opening selesai dan gambar disimpan: JG22.jpg
# Proses opening selesai dan gambar disimpan: JG23.jpg
# Proses opening selesai dan gambar disimpan: JG24.jpg
# Proses opening selesai dan gambar disimpan: JG25.jpg
# Proses opening selesai dan gambar disimpan: JG26.jpg
# Proses opening selesai dan gambar disimpan: JG27.jpg
# Proses opening selesai dan gambar disimpan: JG28.jpg
# Proses opening selesai dan gambar disimpan: JG29.jpg
# Proses opening selesai dan gambar disimpan: JG3.jpg
# Proses opening selesai dan gambar disimpan: JG30.jpg
# Proses opening selesai dan gambar disimpan: JG31.jpg
# Proses opening selesai dan gambar disimpan: JG32.jpg
# Proses opening selesai dan gambar disimpan: JG33.jpg
# Proses opening selesai dan gambar disimpan: JG34.jpg
# Proses opening selesai dan gambar disimpan: JG35.jpg
# Proses opening selesai dan gambar disimpan: JG36.jpg
# Proses opening selesai dan gambar disimpan: JG37.jpg
# Proses opening selesai dan gambar disimpan: JG38.jpg
# Proses opening selesai dan gambar disimpan: JG39.jpg
# Proses opening selesai dan gambar disimpan: JG4.jpg
# Proses opening selesai dan gambar disimpan: JG40.jpg
# Proses opening selesai dan gambar disimpan: JG41.jpg
# Proses opening selesai dan gambar disimpan: JG42.jpg
# Proses opening selesai dan gambar disimpan: JG43.jpg
# Proses opening selesai dan gambar disimpan: JG44.jpg
# Proses opening selesai dan gambar disimpan: JG45.jpg
# Proses opening selesai dan gambar disimpan: JG46.jpg
# Proses opening selesai dan gambar disimpan: JG47.jpg
# Proses opening selesai dan gambar disimpan: JG48.jpg
# Proses opening selesai dan gambar disimpan: JG49.jpg
# Proses opening selesai dan gambar disimpan: JG5.jpg
# Proses opening selesai dan gambar disimpan: JG50.jpg
# Proses opening selesai dan gambar disimpan: JG51.jpg
# Proses opening selesai dan gambar disimpan: JG52.jpg
# Proses opening selesai dan gambar disimpan: JG53.jpg
# Proses opening selesai dan gambar disimpan: JG54.jpg
# Proses opening selesai dan gambar disimpan: JG55.jpg
# Proses opening selesai dan gambar disimpan: JG56.jpg
# Proses opening selesai dan gambar disimpan: JG57.jpg
# Proses opening selesai dan gambar disimpan: JG58.jpg
# Proses opening selesai dan gambar disimpan: JG59.jpg
# Proses opening selesai dan gambar disimpan: JG6.jpg
# Proses opening selesai dan gambar disimpan: JG60.jpg
# Proses opening selesai dan gambar disimpan: JG7.jpg
# Proses opening selesai dan gambar disimpan: JG8.jpg
# Proses opening selesai dan gambar disimpan: JG9.jpg
# Proses opening selesai untuk semua gambar.

# %%
import cv2
import os

# Path direktori
input_dir = 'PREPROCESSING/Jajar Genjang Opening'
output_dir = 'PREPROCESSING/Jajar Genjang Edge Detection'
# Memastikan direktori output ada
os.makedirs(output_dir, exist_ok=True)

# Mendapatkan daftar file di direktori input
file_list = os.listdir(input_dir)

# Parameter untuk deteksi tepi Canny
low_threshold = 50
high_threshold = 150

# Memproses setiap file gambar
for file_name in file_list:
    # Membaca gambar
    input_path = os.path.join(input_dir, file_name)
    image = cv2.imread(input_path, cv2.IMREAD_GRAYSCALE)

    # Memeriksa apakah gambar berhasil dibaca
    if image is None:
        print(f"Gagal membaca {file_name}")
        continue

    # Melakukan deteksi tepi menggunakan algoritma Canny
    edges = cv2.Canny(image, low_threshold, high_threshold)

    # Menyimpan gambar hasil deteksi tepi di direktori output
    output_path = os.path.join(output_dir, file_name)
    cv2.imwrite(output_path, edges)

    print(f"Proses deteksi tepi selesai dan gambar disimpan: {file_name}")

print("Proses deteksi tepi selesai untuk semua gambar.")
# Out:
# Proses deteksi tepi selesai dan gambar disimpan: JG1.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG10.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG11.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG12.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG13.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG14.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG15.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG16.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG17.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG18.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG19.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG2.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG20.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG21.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG22.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG23.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG24.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG25.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG26.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG27.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG28.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG29.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG3.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG30.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG31.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG32.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG33.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG34.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG35.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG36.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG37.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG38.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG39.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG4.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG40.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG41.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG42.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG43.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG44.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG45.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG46.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG47.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG48.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG49.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG5.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG50.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG51.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG52.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG53.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG54.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG55.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG56.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG57.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG58.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG59.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG6.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG60.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG7.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG8.jpg
# Proses deteksi tepi selesai dan gambar disimpan: JG9.jpg
# Proses deteksi tepi selesai untuk semua gambar.

# %%
import cv2
import numpy as np
import os

# Path direktori input dan output
input_dir = 'PREPROCESSING/Jajar Genjang Edge Detection'
output_dir = 'PREPROCESSING/Jajar Genjang LHT'

# Memastikan direktori output ada
os.makedirs(output_dir, exist_ok=True)

# Ekstensi file gambar yang didukung
supported_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.tif')

# Fungsi untuk melakukan deteksi garis menggunakan Hough Line Transform Probabilistic
def hough_transform(image_path, output_path, line_thickness=3):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    edges = cv2.Canny(img, 50, 150, apertureSize=3)
    
    img_new = edges.copy()
    lines = cv2.HoughLinesP(img_new, rho=1, theta=np.pi/180, threshold=3, minLineLength=0, maxLineGap=15)
    
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line[0]
            cv2.line(img_new, (x1, y1), (x2, y2), (255, 255, 255), line_thickness)
    
    cv2.imwrite(output_path, img_new)

# Looping melalui setiap file gambar dalam direktori input
for filename in os.listdir(input_dir):
    if filename.lower().endswith(supported_extensions):
        image_path = os.path.join(input_dir, filename)
        output_path = os.path.join(output_dir, filename)
        # Lakukan Hough Transform dan simpan hasilnya dengan ketebalan garis 5
        hough_transform(image_path, output_path, line_thickness=50)
        print(f"Proses Hough Transform selesai dan gambar disimpan: {filename}")

print("Proses Hough Transform selesai untuk semua gambar.")
# Out:
# Proses Hough Transform selesai dan gambar disimpan: JG1.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG10.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG11.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG12.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG13.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG14.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG15.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG16.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG17.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG18.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG19.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG2.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG20.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG21.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG22.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG23.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG24.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG25.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG26.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG27.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG28.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG29.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG3.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG30.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG31.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG32.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG33.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG34.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG35.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG36.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG37.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG38.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG39.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG4.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG40.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG41.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG42.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG43.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG44.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG45.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG46.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG47.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG48.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG49.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG5.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG50.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG51.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG52.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG53.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG54.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG55.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG56.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG57.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG58.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG59.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG6.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG60.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG7.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG8.jpg
# Proses Hough Transform selesai dan gambar disimpan: JG9.jpg
# Proses Hough Transform selesai untuk semua gambar.

# %%
import os
import cv2
import numpy as np
import csv

def freeman_chain_code(contour):
    chain_code = []
    for i in range(len(contour)):
        current = contour[i][0]
        next = contour[(i + 1) % len(contour)][0]
        dx = next[0] - current[0]
        dy = next[1] - current[1]
        if dx == 1 and dy == 0:
            chain_code.append(0)
        elif dx == 1 and dy == -1:
            chain_code.append(1)
        elif dx == 0 and dy == -1:
            chain_code.append(2)
        elif dx == -1 and dy == -1:
            chain_code.append(3)
        elif dx == -1 and dy == 0:
            chain_code.append(4)
        elif dx == -1 and dy == 1:
            chain_code.append(5)
        elif dx == 0 and dy == 1:
            chain_code.append(6)
        elif dx == 1 and dy == 1:
            chain_code.append(7)
    return chain_code

def process_images(folder_path, output_csv):
    with open(output_csv, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["Image", "7-Digit Output"])
        
        for filename in os.listdir(folder_path):
            if filename.endswith(('.png', '.jpg', '.jpeg')):
                img_path = os.path.join(folder_path, filename)
                img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                
                # Find contours
                contours, _ = cv2.findContours(img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                
                if contours:
                    # Get the largest contour
                    largest_contour = max(contours, key=cv2.contourArea)
                    
                    # Calculate Freeman Chain Code
                    chain_code = freeman_chain_code(largest_contour)
                    
                    # Get the first 3 digits of the chain code
                    first_three = chain_code[:3] if len(chain_code) >= 3 else chain_code
                    
                    # Append the fixed 4-digit sequence 5-0-1-4
                    output = first_three + [5, 0, 1, 4]
                    
                    # Write to CSV
                    writer.writerow([filename, output])
                    
                    # Print the output
                    print(f"Image: {filename}")
                    print(f"Output: {output}")
                    print()

# Usage
folder_path = 'PREPROCESSING/JAJAR GENJANG LHT'
output_csv = 'KODE RANTAI/J.csv'
process_images(folder_path, output_csv)
# Out:
# Image: JG1.jpg
# 7-Digit Output: [6, 7, 1, 5, 0, 1, 4]
#
# Image: JG10.jpg
# 7-Digit Output: [7, 5, 6, 5, 0, 1, 4]
#
# Image: JG11.jpg
# 7-Digit Output: [5, 6, 5, 5, 0, 1, 4]
#
# Image: JG12.jpg
# 7-Digit Output: [7, 6, 7, 5, 0, 1, 4]
#
# Image: JG13.jpg
# 7-Digit Output: [5, 4, 7, 5, 0, 1, 4]
#
# Image: JG14.jpg
# 7-Digit Output: [0, 7, 6, 5, 0, 1, 4]
#
# Image: JG15.jpg
# 7-Digit Output: [5, 0, 7, 5, 0, 1, 4]
#
# Image: JG16.jpg
# 7-Digit Output: [5, 4, 7, 5, 0, 1, 4]
#
# Image: JG17.jpg
# 7-Digit Output: [6, 6, 5, 5, 0, 1, 4]
#
# Image: JG18.jpg
# 7-Digit Output: [5, 0, 7, 5, 0, 1, 4]
#
# Image: JG19.jpg
# 7-Digit Output: [6, 7, 6, 5, 0, 1, 4]
#
# Image: JG2.jpg
# 7-Digit Output: [6, 7, 6, 5, 0, 1, 4]
#
# Image: JG20.jpg
# 7-Digit Output: [7, 5, 3, 5, 0, 1, 4]
#
# Image: JG21.jpg
# 7-Digit Output: [7, 5, 6, 5, 0, 1, 4]
#
# Image: JG22.jpg
# 7-Digit Output: [7, 6, 0, 5, 0, 1, 4]
#
# Image: JG23.jpg
# 7-Digit Output: [6, 7, 6, 5, 0, 1, 4]
#
# Image: JG24.jpg
# 7-Digit Output: [3, 7, 1, 5, 0, 1, 4]
#
# Image: JG25.jpg
# 7-Digit Output: [6, 6, 5, 5, 0, 1, 4]
#
# Image: JG26.jpg
# 7-Digit Output: [0, 7, 5, 5, 0, 1, 4]
#
# Image: JG27.jpg
# 7-Digit Output: [5, 4, 6, 5, 0, 1, 4]
#
# Image: JG28.jpg
# 7-Digit Output: [6, 7, 5, 5, 0, 1, 4]
#
# Image: JG29.jpg
# 7-Digit Output: [4, 3, 3, 5, 0, 1, 4]
#
# Image: JG3.jpg
# 7-Digit Output: [7, 5, 3, 5, 0, 1, 4]
#
# Image: JG30.jpg
# 7-Digit Output: [7, 6, 5, 5, 0, 1, 4]
#
# Image: JG31.jpg
# 7-Digit Output: [7, 5, 3, 5, 0, 1, 4]
#
# Image: JG32.jpg
# 7-Digit Output: [6, 5, 5, 5, 0, 1, 4]
#
# Image: JG33.jpg
# 7-Digit Output: [7, 6, 7, 5, 0, 1, 4]
#
# Image: JG34.jpg
# 7-Digit Output: [6, 5, 3, 5, 0, 1, 4]
#
# Image: JG35.jpg
# 7-Digit Output: [5, 4, 7, 5, 0, 1, 4]
#
# Image: JG36.jpg
# 7-Digit Output: [5, 5, 4, 5, 0, 1, 4]
#
# Image: JG37.jpg
# 7-Digit Output: [6, 5, 7, 5, 0, 1, 4]
#
# Image: JG38.jpg
# 7-Digit Output: [7, 3, 3, 5, 0, 1, 4]
#
# Image: JG39.jpg
# 7-Digit Output: [6, 5, 4, 5, 0, 1, 4]
#
# Image: JG4.jpg
# 7-Digit Output: [5, 4, 7, 5, 0, 1, 4]
#
# Image: JG40.jpg
# 7-Digit Output: [5, 0, 7, 5, 0, 1, 4]
#
# Image: JG41.jpg
# 7-Digit Output: [3, 7, 5, 5, 0, 1, 4]
#
# Image: JG42.jpg
# 7-Digit Output: [6, 7, 5, 5, 0, 1, 4]
#
# Image: JG43.jpg
# 7-Digit Output: [1, 7, 6, 5, 0, 1, 4]
#
# Image: JG44.jpg
# 7-Digit Output: [6, 0, 7, 5, 0, 1, 4]
#
# Image: JG45.jpg
# 7-Digit Output: [3, 7, 1, 5, 0, 1, 4]
#
# Image: JG46.jpg
# 7-Digit Output: [6, 7, 5, 5, 0, 1, 4]
#
# Image: JG47.jpg
# 7-Digit Output: [6, 7, 1, 5, 0, 1, 4]
#
# Image: JG48.jpg
# 7-Digit Output: [5, 6, 1, 5, 0, 1, 4]
#
# Image: JG49.jpg
# 7-Digit Output: [5, 0, 7, 5, 0, 1, 4]
#
# Image: JG5.jpg
# 7-Digit Output: [6, 3, 7, 5, 0, 1, 4]
#
# Image: JG50.jpg
# 7-Digit Output: [5, 4, 0, 5, 0, 1, 4]
#
# Image: JG51.jpg
# 7-Digit Output: [5, 7, 5, 5, 0, 1, 4]
#
# Image: JG52.jpg
# 7-Digit Output: [7, 6, 7, 5, 0, 1, 4]
#
# Image: JG53.jpg
# 7-Digit Output: [7, 6, 6, 5, 0, 1, 4]
#
# Image: JG54.jpg
# 7-Digit Output: [6, 7, 1, 5, 0, 1, 4]
#
# Image: JG55.jpg
# 7-Digit Output: [6, 5, 3, 5, 0, 1, 4]
#
# Image: JG56.jpg
# 7-Digit Output: [5, 7, 5, 5, 0, 1, 4]
#
# Image: JG57.jpg
# 7-Digit Output: [4, 3, 3, 5, 0, 1, 4]
#
# Image: JG58.jpg
# 7-Digit Output: [5, 4, 7, 5, 0, 1, 4]
#
# Image: JG59.jpg
# 7-Digit Output: [6, 7, 1, 5, 0, 1, 4]
#
# Image: JG6.jpg
# 7-Digit Output: [0, 7, 6, 5, 0, 1, 4]
#
# Image: JG60.jpg
# 7-Digit Output: [6, 5, 4, 5, 0, 1, 4]
#
# Image: JG7.jpg
# 7-Digit Output: [6, 5, 7, 5, 0, 1, 4]
#
# Image: JG8.jpg
# 7-Digit Output: [7, 6, 4, 5, 0, 1, 4]
#
# Image: JG9.jpg
# 7-Digit Output: [3, 7, 1, 5, 0, 1, 4]
