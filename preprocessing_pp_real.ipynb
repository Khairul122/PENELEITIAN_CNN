# %%
import cv2
import numpy as np
import os
import zipfile

# Paths provided by you
input_dir = 'Citra Real/Persegi Panjang'
output_dir = 'PREPROCESSING/Persegi Panjang Segmented'

# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)

# Define the range of purple color in HSV
lower_purple = np.array([0, 150, 100])
upper_purple = np.array([10, 255, 255])

# Process each image in the input directory
for filename in os.listdir(input_dir):
    if filename.endswith(('.png', '.jpg', '.jpeg')):
        # Load the image
        image_path = os.path.join(input_dir, filename)
        image = cv2.imread(image_path)
        
        # Convert the image to HSV color space
        hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
        
        # Create a mask for the purple color
        mask = cv2.inRange(hsv, lower_purple, upper_purple)
        
        # Apply the mask to get the segmented image
        segmented_image = cv2.bitwise_and(image, image, mask=mask)
        
        # Save the segmented image
        output_path = os.path.join(output_dir, filename)
        cv2.imwrite(output_path, segmented_image)
        
        print(f'Segmented image saved: {output_path}')
# Out:
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP1.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP10.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP11.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP12.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP13.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP14.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP15.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP16.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP17.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP18.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP19.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP2.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP20.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP21.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP22.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP23.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP24.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP25.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP26.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP27.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP28.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP29.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP3.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP30.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP31.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP32.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP33.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP34.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP35.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP36.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP37.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP38.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP39.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP4.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP40.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP41.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP42.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP43.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP44.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP45.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP46.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP47.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP48.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP49.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP5.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP50.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP51.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP52.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP53.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP54.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP55.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP56.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP57.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP58.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP59.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP6.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP60.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP61.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP7.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP8.jpg
# Segmented image saved: PREPROCESSING/Persegi Panjang Segmented\PP9.jpg

# %%
import cv2
import os

# Directory paths
segmented_dir = 'PREPROCESSING/Persegi Panjang Segmented'
grayscale_output_dir = 'PREPROCESSING/Persegi Panjang Grayscale'

# Ensure the output directory exists
os.makedirs(grayscale_output_dir, exist_ok=True)

# Process each image in the segmented directory
for filename in os.listdir(segmented_dir):
    if filename.endswith(('.png', '.jpg', '.jpeg')):
        # Load the segmented image
        segmented_image_path = os.path.join(segmented_dir, filename)
        segmented_image = cv2.imread(segmented_image_path)
        
        # Convert the image to grayscale
        grayscale_image = cv2.cvtColor(segmented_image, cv2.COLOR_BGR2GRAY)
        
        # Save the grayscale image
        grayscale_image_path = os.path.join(grayscale_output_dir, filename)
        cv2.imwrite(grayscale_image_path, grayscale_image)
        
        print(f'Grayscale image saved: {grayscale_image_path}')
# Out:
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP1.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP10.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP11.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP12.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP13.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP14.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP15.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP16.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP17.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP18.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP19.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP2.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP20.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP21.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP22.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP23.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP24.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP25.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP26.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP27.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP28.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP29.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP3.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP30.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP31.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP32.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP33.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP34.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP35.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP36.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP37.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP38.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP39.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP4.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP40.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP41.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP42.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP43.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP44.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP45.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP46.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP47.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP48.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP49.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP5.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP50.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP51.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP52.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP53.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP54.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP55.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP56.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP57.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP58.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP59.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP6.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP60.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP61.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP7.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP8.jpg
# Grayscale image saved: PREPROCESSING/Persegi Panjang Grayscale\PP9.jpg

# %%
import cv2
import os

# Directory paths
input_dir = 'PREPROCESSING/Persegi Panjang Grayscale'
output_dir = 'PREPROCESSING/Persegi Panjang Binary'

# Memastikan direktori output ada
os.makedirs(output_dir, exist_ok=True)

# Mendapatkan daftar file di direktori input
file_list = os.listdir(input_dir)

# Memproses setiap file gambar
for file_name in file_list:
    # Membaca gambar
    input_path = os.path.join(input_dir, file_name)
    image = cv2.imread(input_path, cv2.IMREAD_GRAYSCALE)  # Membaca langsung sebagai grayscale

    # Memeriksa apakah gambar berhasil dibaca
    if image is None:
        print(f"Failed to read {file_name}")
        continue

    # Mengonversi gambar grayscale menjadi citra biner menggunakan thresholding dengan tipe binary
    _, binary_image = cv2.threshold(image, 10, 255, cv2.THRESH_BINARY)
    
    # Menghilangkan noise menggunakan median blur
    denoised_image = cv2.medianBlur(binary_image, 5)  # Kernel size 5

    # Menyimpan gambar biner di direktori output
    output_path = os.path.join(output_dir, file_name)
    cv2.imwrite(output_path, denoised_image)

    print(f"Processed and saved: {file_name}")

print("Processing complete.")
# Out:
# Processed and saved: PP1.jpg
# Processed and saved: PP10.jpg
# Processed and saved: PP11.jpg
# Processed and saved: PP12.jpg
# Processed and saved: PP13.jpg
# Processed and saved: PP14.jpg
# Processed and saved: PP15.jpg
# Processed and saved: PP16.jpg
# Processed and saved: PP17.jpg
# Processed and saved: PP18.jpg
# Processed and saved: PP19.jpg
# Processed and saved: PP2.jpg
# Processed and saved: PP20.jpg
# Processed and saved: PP21.jpg
# Processed and saved: PP22.jpg
# Processed and saved: PP23.jpg
# Processed and saved: PP24.jpg
# Processed and saved: PP25.jpg
# Processed and saved: PP26.jpg
# Processed and saved: PP27.jpg
# Processed and saved: PP28.jpg
# Processed and saved: PP29.jpg
# Processed and saved: PP3.jpg
# Processed and saved: PP30.jpg
# Processed and saved: PP31.jpg
# Processed and saved: PP32.jpg
# Processed and saved: PP33.jpg
# Processed and saved: PP34.jpg
# Processed and saved: PP35.jpg
# Processed and saved: PP36.jpg
# Processed and saved: PP37.jpg
# Processed and saved: PP38.jpg
# Processed and saved: PP39.jpg
# Processed and saved: PP4.jpg
# Processed and saved: PP40.jpg
# Processed and saved: PP41.jpg
# Processed and saved: PP42.jpg
# Processed and saved: PP43.jpg
# Processed and saved: PP44.jpg
# Processed and saved: PP45.jpg
# Processed and saved: PP46.jpg
# Processed and saved: PP47.jpg
# Processed and saved: PP48.jpg
# Processed and saved: PP49.jpg
# Processed and saved: PP5.jpg
# Processed and saved: PP50.jpg
# Processed and saved: PP51.jpg
# Processed and saved: PP52.jpg
# Processed and saved: PP53.jpg
# Processed and saved: PP54.jpg
# Processed and saved: PP55.jpg
# Processed and saved: PP56.jpg
# Processed and saved: PP57.jpg
# Processed and saved: PP58.jpg
# Processed and saved: PP59.jpg
# Processed and saved: PP6.jpg
# Processed and saved: PP60.jpg
# Processed and saved: PP61.jpg
# Processed and saved: PP7.jpg
# Processed and saved: PP8.jpg
# Processed and saved: PP9.jpg
# Processing complete.

# %%
import cv2
import numpy as np
import os

# Path direktori
input_dir = 'PREPROCESSING/Persegi Panjang Binary'
output_dir = 'PREPROCESSING/Persegi Panjang Filled'

# Memastikan direktori output ada
os.makedirs(output_dir, exist_ok=True)

# Mendapatkan daftar file di direktori input
file_list = os.listdir(input_dir)

# Memproses setiap file gambar
for file_name in file_list:
    # Membaca gambar
    input_path = os.path.join(input_dir, file_name)
    image = cv2.imread(input_path, cv2.IMREAD_GRAYSCALE)

    # Memeriksa apakah gambar berhasil dibaca
    if image is None:
        print(f"Gagal membaca {file_name}")
        continue

    # Gaussian Blur untuk mengurangi noise
    blurred_image = cv2.GaussianBlur(image, (5, 5), 0)

    # Membuat invers dari gambar biner
    inv_image = cv2.bitwise_not(blurred_image)

    # Melakukan flood fill dari sudut gambar
    h, w = inv_image.shape[:2]
    mask = np.zeros((h+2, w+2), np.uint8)  # Membuat mask dengan tambahan border
    cv2.floodFill(inv_image, mask, (0, 0), 255)

    # Membuat invers kembali untuk mendapatkan hasil citra yang filled
    filled_image = cv2.bitwise_not(inv_image)

    # Menggabungkan hasil filled dengan citra biner asli
    final_image = cv2.bitwise_or(image, filled_image)
    
    # Proses filling tambahan menggunakan kontur
    ret, thresh = cv2.threshold(final_image, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cv2.drawContours(final_image, contours, -1, (255), thickness=cv2.FILLED)

    # Operasi morfologi untuk menghilangkan noise lebih lanjut
    kernel = np.ones((3, 3), np.uint8)
    final_image = cv2.morphologyEx(final_image, cv2.MORPH_OPEN, kernel)

    # Menyimpan gambar hasil filling di direktori output
    output_path = os.path.join(output_dir, file_name)
    cv2.imwrite(output_path, final_image)

    print(f"Proses filling dan penyimpanan selesai untuk: {file_name}")

print("Proses filling selesai.")
# Out:
# Proses filling dan penyimpanan selesai untuk: PP1.jpg
# Proses filling dan penyimpanan selesai untuk: PP10.jpg
# Proses filling dan penyimpanan selesai untuk: PP11.jpg
# Proses filling dan penyimpanan selesai untuk: PP12.jpg
# Proses filling dan penyimpanan selesai untuk: PP13.jpg
# Proses filling dan penyimpanan selesai untuk: PP14.jpg
# Proses filling dan penyimpanan selesai untuk: PP15.jpg
# Proses filling dan penyimpanan selesai untuk: PP16.jpg
# Proses filling dan penyimpanan selesai untuk: PP17.jpg
# Proses filling dan penyimpanan selesai untuk: PP18.jpg
# Proses filling dan penyimpanan selesai untuk: PP19.jpg
# Proses filling dan penyimpanan selesai untuk: PP2.jpg
# Proses filling dan penyimpanan selesai untuk: PP20.jpg
# Proses filling dan penyimpanan selesai untuk: PP21.jpg
# Proses filling dan penyimpanan selesai untuk: PP22.jpg
# Proses filling dan penyimpanan selesai untuk: PP23.jpg
# Proses filling dan penyimpanan selesai untuk: PP24.jpg
# Proses filling dan penyimpanan selesai untuk: PP25.jpg
# Proses filling dan penyimpanan selesai untuk: PP26.jpg
# Proses filling dan penyimpanan selesai untuk: PP27.jpg
# Proses filling dan penyimpanan selesai untuk: PP28.jpg
# Proses filling dan penyimpanan selesai untuk: PP29.jpg
# Proses filling dan penyimpanan selesai untuk: PP3.jpg
# Proses filling dan penyimpanan selesai untuk: PP30.jpg
# Proses filling dan penyimpanan selesai untuk: PP31.jpg
# Proses filling dan penyimpanan selesai untuk: PP32.jpg
# Proses filling dan penyimpanan selesai untuk: PP33.jpg
# Proses filling dan penyimpanan selesai untuk: PP34.jpg
# Proses filling dan penyimpanan selesai untuk: PP35.jpg
# Proses filling dan penyimpanan selesai untuk: PP36.jpg
# Proses filling dan penyimpanan selesai untuk: PP37.jpg
# Proses filling dan penyimpanan selesai untuk: PP38.jpg
# Proses filling dan penyimpanan selesai untuk: PP39.jpg
# Proses filling dan penyimpanan selesai untuk: PP4.jpg
# Proses filling dan penyimpanan selesai untuk: PP40.jpg
# Proses filling dan penyimpanan selesai untuk: PP41.jpg
# Proses filling dan penyimpanan selesai untuk: PP42.jpg
# Proses filling dan penyimpanan selesai untuk: PP43.jpg
# Proses filling dan penyimpanan selesai untuk: PP44.jpg
# Proses filling dan penyimpanan selesai untuk: PP45.jpg
# Proses filling dan penyimpanan selesai untuk: PP46.jpg
# Proses filling dan penyimpanan selesai untuk: PP47.jpg
# Proses filling dan penyimpanan selesai untuk: PP48.jpg
# Proses filling dan penyimpanan selesai untuk: PP49.jpg
# Proses filling dan penyimpanan selesai untuk: PP5.jpg
# Proses filling dan penyimpanan selesai untuk: PP50.jpg
# Proses filling dan penyimpanan selesai untuk: PP51.jpg
# Proses filling dan penyimpanan selesai untuk: PP52.jpg
# Proses filling dan penyimpanan selesai untuk: PP53.jpg
# Proses filling dan penyimpanan selesai untuk: PP54.jpg
# Proses filling dan penyimpanan selesai untuk: PP55.jpg
# Proses filling dan penyimpanan selesai untuk: PP56.jpg
# Proses filling dan penyimpanan selesai untuk: PP57.jpg
# Proses filling dan penyimpanan selesai untuk: PP58.jpg
# Proses filling dan penyimpanan selesai untuk: PP59.jpg
# Proses filling dan penyimpanan selesai untuk: PP6.jpg
# Proses filling dan penyimpanan selesai untuk: PP60.jpg
# Proses filling dan penyimpanan selesai untuk: PP61.jpg
# Proses filling dan penyimpanan selesai untuk: PP7.jpg
# Proses filling dan penyimpanan selesai untuk: PP8.jpg
# Proses filling dan penyimpanan selesai untuk: PP9.jpg
# Proses filling selesai.

# %%
import cv2
import os
import numpy as np

# Path direktori
input_dir = 'PREPROCESSING/Persegi Panjang Filled'
output_dir = 'PREPROCESSING/Persegi Panjang Opening'

# Memastikan direktori output ada
os.makedirs(output_dir, exist_ok=True)

# Mendapatkan daftar file di direktori input
file_list = os.listdir(input_dir)

# Mendefinisikan elemen struktural (kernel) untuk operasi morfologi
kernel = np.ones((5, 5), np.uint8)  # Kernel ukuran 5x5, dapat disesuaikan

# Memproses setiap file gambar
for file_name in file_list:
    # Membaca gambar
    input_path = os.path.join(input_dir, file_name)
    image = cv2.imread(input_path, cv2.IMREAD_GRAYSCALE)

    # Memeriksa apakah gambar berhasil dibaca
    if image is None:
        print(f"Gagal membaca {file_name}")
        continue

    # Melakukan iterasi proses erosi dan dilasi sebanyak 30 kali
    for _ in range(30):
        # Erosi
        eroded_image = cv2.erode(image, kernel, iterations=100)
        # Dilasi
        image = cv2.dilate(eroded_image, kernel, iterations=100)

    # Menyimpan gambar hasil erosi dan dilasi di direktori output
    output_path = os.path.join(output_dir, file_name)
    cv2.imwrite(output_path, image)

    print(f"Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: {file_name}")

print("Proses erosi dan dilasi selesai untuk semua gambar.")
# Out:
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP1.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP10.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP11.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP12.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP13.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP14.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP15.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP16.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP17.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP18.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP19.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP2.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP20.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP21.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP22.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP23.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP24.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP25.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP26.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP27.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP28.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP29.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP3.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP30.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP31.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP32.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP33.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP34.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP35.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP36.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP37.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP38.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP39.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP4.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP40.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP41.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP42.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP43.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP44.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP45.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP46.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP47.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP48.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP49.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP5.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP50.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP51.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP52.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP53.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP54.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP55.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP56.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP57.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP58.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP59.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP6.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP60.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP61.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP7.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP8.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: PP9.jpg
# Proses erosi dan dilasi selesai untuk semua gambar.

# %%
import cv2
import os

# Path direktori
input_dir = 'PREPROCESSING/Persegi Panjang Opening'
output_dir = 'PREPROCESSING/Persegi Panjang Edge Detection'
# Memastikan direktori output ada
os.makedirs(output_dir, exist_ok=True)

# Mendapatkan daftar file di direktori input
file_list = os.listdir(input_dir)

# Parameter untuk deteksi tepi Canny
low_threshold = 50
high_threshold = 150

# Memproses setiap file gambar
for file_name in file_list:
    # Membaca gambar
    input_path = os.path.join(input_dir, file_name)
    image = cv2.imread(input_path, cv2.IMREAD_GRAYSCALE)

    # Memeriksa apakah gambar berhasil dibaca
    if image is None:
        print(f"Gagal membaca {file_name}")
        continue

    # Melakukan deteksi tepi menggunakan algoritma Canny
    edges = cv2.Canny(image, low_threshold, high_threshold)

    # Menyimpan gambar hasil deteksi tepi di direktori output
    output_path = os.path.join(output_dir, file_name)
    cv2.imwrite(output_path, edges)

    print(f"Proses deteksi tepi selesai dan gambar disimpan: {file_name}")

print("Proses deteksi tepi selesai untuk semua gambar.")
# Out:
# Proses deteksi tepi selesai dan gambar disimpan: PP1.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP10.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP11.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP12.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP13.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP14.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP15.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP16.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP17.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP18.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP19.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP2.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP20.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP21.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP22.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP23.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP24.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP25.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP26.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP27.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP28.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP29.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP3.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP30.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP31.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP32.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP33.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP34.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP35.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP36.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP37.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP38.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP39.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP4.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP40.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP41.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP42.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP43.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP44.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP45.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP46.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP47.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP48.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP49.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP5.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP50.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP51.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP52.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP53.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP54.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP55.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP56.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP57.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP58.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP59.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP6.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP60.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP61.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP7.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP8.jpg
# Proses deteksi tepi selesai dan gambar disimpan: PP9.jpg
# Proses deteksi tepi selesai untuk semua gambar.

# %%
import cv2
import numpy as np
import os

# Path direktori input dan output
input_dir = 'PREPROCESSING/Persegi Panjang Edge Detection'
output_dir = 'PREPROCESSING/Persegi Panjang LHT'

# Memastikan direktori output ada
os.makedirs(output_dir, exist_ok=True)

# Ekstensi file gambar yang didukung
supported_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.tif')

# Fungsi untuk melakukan deteksi garis menggunakan Hough Line Transform Probabilistic
def hough_transform(image_path, output_path, line_thickness=3):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    edges = cv2.Canny(img, 50, 150, apertureSize=3)
    
    img_new = edges.copy()
    lines = cv2.HoughLinesP(img_new, rho=1, theta=np.pi/180, threshold=3, minLineLength=0, maxLineGap=15)
    
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line[0]
            cv2.line(img_new, (x1, y1), (x2, y2), (255, 255, 255), line_thickness)
    
    cv2.imwrite(output_path, img_new)

# Looping melalui setiap file gambar dalam direktori input
for filename in os.listdir(input_dir):
    if filename.lower().endswith(supported_extensions):
        image_path = os.path.join(input_dir, filename)
        output_path = os.path.join(output_dir, filename)
        # Lakukan Hough Transform dan simpan hasilnya dengan ketebalan garis 5
        hough_transform(image_path, output_path, line_thickness=50)
        print(f"Proses Hough Transform selesai dan gambar disimpan: {filename}")

print("Proses Hough Transform selesai untuk semua gambar.")
# Out:
# Proses Hough Transform selesai dan gambar disimpan: PP1.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP10.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP11.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP12.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP13.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP14.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP15.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP16.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP17.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP18.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP19.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP2.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP20.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP21.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP22.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP23.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP24.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP25.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP26.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP27.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP28.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP29.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP3.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP30.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP31.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP32.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP33.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP34.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP35.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP36.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP37.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP38.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP39.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP4.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP40.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP41.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP42.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP43.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP44.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP45.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP46.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP47.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP48.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP49.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP5.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP50.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP51.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP52.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP53.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP54.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP55.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP56.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP57.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP58.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP59.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP6.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP60.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP61.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP7.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP8.jpg
# Proses Hough Transform selesai dan gambar disimpan: PP9.jpg
# Proses Hough Transform selesai untuk semua gambar.

# %%
import os
import cv2
import numpy as np
import csv

def freeman_chain_code(contour):
    chain_code = []
    for i in range(len(contour)):
        current = contour[i][0]
        next = contour[(i + 1) % len(contour)][0]
        dx = next[0] - current[0]
        dy = next[1] - current[1]
        if dx == 1 and dy == 0:
            chain_code.append(0)
        elif dx == 1 and dy == -1:
            chain_code.append(1)
        elif dx == 0 and dy == -1:
            chain_code.append(2)
        elif dx == -1 and dy == -1:
            chain_code.append(3)
        elif dx == -1 and dy == 0:
            chain_code.append(4)
        elif dx == -1 and dy == 1:
            chain_code.append(5)
        elif dx == 0 and dy == 1:
            chain_code.append(6)
        elif dx == 1 and dy == 1:
            chain_code.append(7)
    return chain_code

def process_images(folder_path, output_csv):
    with open(output_csv, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["Image", "7-Digit Output"])
        
        for filename in os.listdir(folder_path):
            if filename.endswith(('.png', '.jpg', '.jpeg')):
                img_path = os.path.join(folder_path, filename)
                img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                
                # Find contours
                contours, _ = cv2.findContours(img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                
                if contours:
                    # Get the largest contour
                    largest_contour = max(contours, key=cv2.contourArea)
                    
                    # Calculate Freeman Chain Code
                    chain_code = freeman_chain_code(largest_contour)
                    
                    # Get the first 3 digits of the chain code
                    first_three = chain_code[:3] if len(chain_code) >= 3 else chain_code
                    
                    # Append the fixed 4-digit sequence 5-0-1-4
                    output = first_three + [6, 0, 2, 4]
                    
                    # Write to CSV
                    writer.writerow([filename, output])
                    
                    # Print the output
                    print(f"Image: {filename}")
                    print(f"Output: {output}")
                    print()

# Usage
folder_path = 'PREPROCESSING/Persegi Panjang LHT'
output_csv = 'KODE RANTAI/PP.csv'
process_images(folder_path, output_csv)
# Out:
# Image: PP1.jpg
# 7-Digit Output: [6, 5, 3, 6, 0, 2, 4]
#
# Image: PP10.jpg
# 7-Digit Output: [7, 6, 7, 6, 0, 2, 4]
#
# Image: PP11.jpg
# 7-Digit Output: [6, 5, 3, 6, 0, 2, 4]
#
# Image: PP12.jpg
# 7-Digit Output: [7, 6, 5, 6, 0, 2, 4]
#
# Image: PP13.jpg
# 7-Digit Output: [5, 5, 4, 6, 0, 2, 4]
#
# Image: PP14.jpg
# 7-Digit Output: [5, 4, 6, 6, 0, 2, 4]
#
# Image: PP15.jpg
# 7-Digit Output: [5, 4, 5, 6, 0, 2, 4]
#
# Image: PP16.jpg
# 7-Digit Output: [7, 6, 4, 6, 0, 2, 4]
#
# Image: PP17.jpg
# 7-Digit Output: [5, 4, 5, 6, 0, 2, 4]
#
# Image: PP18.jpg
# 7-Digit Output: [3, 2, 3, 6, 0, 2, 4]
#
# Image: PP19.jpg
# 7-Digit Output: [7, 6, 4, 6, 0, 2, 4]
#
# Image: PP2.jpg
# 7-Digit Output: [7, 5, 6, 6, 0, 2, 4]
#
# Image: PP20.jpg
# 7-Digit Output: [7, 5, 3, 6, 0, 2, 4]
#
# Image: PP21.jpg
# 7-Digit Output: [6, 7, 0, 6, 0, 2, 4]
#
# Image: PP22.jpg
# 7-Digit Output: [7, 6, 7, 6, 0, 2, 4]
#
# Image: PP23.jpg
# 7-Digit Output: [5, 0, 7, 6, 0, 2, 4]
#
# Image: PP24.jpg
# 7-Digit Output: [5, 4, 5, 6, 0, 2, 4]
#
# Image: PP25.jpg
# 7-Digit Output: [5, 0, 7, 6, 0, 2, 4]
#
# Image: PP26.jpg
# 7-Digit Output: [7, 6, 5, 6, 0, 2, 4]
#
# Image: PP27.jpg
# 7-Digit Output: [5, 4, 5, 6, 0, 2, 4]
#
# Image: PP28.jpg
# 7-Digit Output: [5, 6, 1, 6, 0, 2, 4]
#
# Image: PP29.jpg
# 7-Digit Output: [7, 6, 7, 6, 0, 2, 4]
#
# Image: PP3.jpg
# 7-Digit Output: [7, 6, 5, 6, 0, 2, 4]
#
# Image: PP30.jpg
# 7-Digit Output: [7, 6, 7, 6, 0, 2, 4]
#
# Image: PP31.jpg
# 7-Digit Output: [6, 3, 7, 6, 0, 2, 4]
#
# Image: PP32.jpg
# 7-Digit Output: [6, 3, 5, 6, 0, 2, 4]
#
# Image: PP33.jpg
# 7-Digit Output: [7, 6, 5, 6, 0, 2, 4]
#
# Image: PP34.jpg
# 7-Digit Output: [5, 0, 7, 6, 0, 2, 4]
#
# Image: PP35.jpg
# 7-Digit Output: [7, 5, 6, 6, 0, 2, 4]
#
# Image: PP36.jpg
# 7-Digit Output: [5, 4, 7, 6, 0, 2, 4]
#
# Image: PP37.jpg
# 7-Digit Output: [5, 4, 7, 6, 0, 2, 4]
#
# Image: PP38.jpg
# 7-Digit Output: [6, 5, 3, 6, 0, 2, 4]
#
# Image: PP39.jpg
# 7-Digit Output: [6, 7, 1, 6, 0, 2, 4]
#
# Image: PP4.jpg
# 7-Digit Output: [6, 7, 5, 6, 0, 2, 4]
#
# Image: PP40.jpg
# 7-Digit Output: [6, 7, 1, 6, 0, 2, 4]
#
# Image: PP41.jpg
# 7-Digit Output: [5, 5, 4, 6, 0, 2, 4]
#
# Image: PP42.jpg
# 7-Digit Output: [5, 4, 5, 6, 0, 2, 4]
#
# Image: PP43.jpg
# 7-Digit Output: [7, 6, 7, 6, 0, 2, 4]
#
# Image: PP44.jpg
# 7-Digit Output: [5, 1, 7, 6, 0, 2, 4]
#
# Image: PP45.jpg
# 7-Digit Output: [6, 7, 6, 6, 0, 2, 4]
#
# Image: PP46.jpg
# 7-Digit Output: [3, 7, 1, 6, 0, 2, 4]
#
# Image: PP47.jpg
# 7-Digit Output: [6, 7, 5, 6, 0, 2, 4]
#
# Image: PP48.jpg
# 7-Digit Output: [7, 0, 7, 6, 0, 2, 4]
#
# Image: PP49.jpg
# 7-Digit Output: [6, 3, 7, 6, 0, 2, 4]
#
# Image: PP5.jpg
# 7-Digit Output: [5, 0, 7, 6, 0, 2, 4]
#
# Image: PP50.jpg
# 7-Digit Output: [6, 7, 1, 6, 0, 2, 4]
#
# Image: PP51.jpg
# 7-Digit Output: [5, 4, 6, 6, 0, 2, 4]
#
# Image: PP52.jpg
# 7-Digit Output: [7, 5, 6, 6, 0, 2, 4]
#
# Image: PP53.jpg
# 7-Digit Output: [7, 0, 7, 6, 0, 2, 4]
#
# Image: PP54.jpg
# 7-Digit Output: [6, 5, 3, 6, 0, 2, 4]
#
# Image: PP55.jpg
# 7-Digit Output: [5, 0, 7, 6, 0, 2, 4]
#
# Image: PP56.jpg
# 7-Digit Output: [6, 5, 3, 6, 0, 2, 4]
#
# Image: PP57.jpg
# 7-Digit Output: [6, 5, 3, 6, 0, 2, 4]
#
# Image: PP58.jpg
# 7-Digit Output: [7, 0, 7, 6, 0, 2, 4]
#
# Image: PP59.jpg
# 7-Digit Output: [7, 0, 7, 6, 0, 2, 4]
#
# Image: PP6.jpg
# 7-Digit Output: [5, 4, 6, 6, 0, 2, 4]
#
# Image: PP60.jpg
# 7-Digit Output: [5, 4, 7, 6, 0, 2, 4]
#
# Image: PP61.jpg
# 7-Digit Output: [6, 7, 1, 6, 0, 2, 4]
#
# Image: PP7.jpg
# 7-Digit Output: [6, 5, 3, 6, 0, 2, 4]
#
# Image: PP8.jpg
# 7-Digit Output: [6, 5, 3, 6, 0, 2, 4]
#
# Image: PP9.jpg
# 7-Digit Output: [6, 7, 5, 6, 0, 2, 4]
