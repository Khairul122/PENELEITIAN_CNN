# %%
import cv2
import numpy as np
import os
import zipfile

# Paths provided by you
input_dir = 'Citra Real/Segitiga'
output_dir = 'PREPROCESSING/segitiga sama sisi Segmented'

# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)

# Define the range of purple color in HSV
lower_purple = np.array([0, 50, 20])
upper_purple = np.array([20, 255, 200])

# Process each image in the input directory
for filename in os.listdir(input_dir):
    if filename.endswith(('.png', '.jpg', '.jpeg')):
        # Load the image
        image_path = os.path.join(input_dir, filename)
        image = cv2.imread(image_path)
        
        # Convert the image to HSV color space
        hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
        
        # Create a mask for the purple color
        mask = cv2.inRange(hsv, lower_purple, upper_purple)
        
        # Apply the mask to get the segmented image
        segmented_image = cv2.bitwise_and(image, image, mask=mask)
        
        # Save the segmented image
        output_path = os.path.join(output_dir, filename)
        cv2.imwrite(output_path, segmented_image)
        
        print(f'Segmented image saved: {output_path}')
# Out:
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S1.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S10.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S11.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S12.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S13.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S14.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S15.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S16.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S17.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S18.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S19.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S2.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S20.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S21.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S22.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S23.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S24.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S25.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S26.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S27.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S28.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S29.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S3.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S30.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S31.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S32.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S33.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S34.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S35.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S36.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S37.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S38.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S39.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S4.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S40.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S41.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S42.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S43.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S44.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S45.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S46.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S47.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S48.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S49.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S5.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S50.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S51.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S52.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S53.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S54.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S55.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S56.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S57.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S58.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S59.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S6.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S60.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S61.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S62.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S7.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S8.jpg
# Segmented image saved: PREPROCESSING/segitiga sama sisi Segmented\S9.jpg

# %%
import cv2
import os

# Directory paths
segmented_dir = 'PREPROCESSING/segitiga sama sisi Segmented'
grayscale_output_dir = 'PREPROCESSING/segitiga sama sisi Grayscale'

# Ensure the output directory exists
os.makedirs(grayscale_output_dir, exist_ok=True)

# Process each image in the segmented directory
for filename in os.listdir(segmented_dir):
    if filename.endswith(('.png', '.jpg', '.jpeg')):
        # Load the segmented image
        segmented_image_path = os.path.join(segmented_dir, filename)
        segmented_image = cv2.imread(segmented_image_path)
        
        # Convert the image to grayscale
        grayscale_image = cv2.cvtColor(segmented_image, cv2.COLOR_BGR2GRAY)
        
        # Save the grayscale image
        grayscale_image_path = os.path.join(grayscale_output_dir, filename)
        cv2.imwrite(grayscale_image_path, grayscale_image)
        
        print(f'Grayscale image saved: {grayscale_image_path}')
# Out:
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S1.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S10.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S11.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S12.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S13.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S14.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S15.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S16.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S17.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S18.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S19.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S2.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S20.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S21.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S22.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S23.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S24.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S25.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S26.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S27.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S28.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S29.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S3.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S30.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S31.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S32.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S33.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S34.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S35.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S36.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S37.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S38.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S39.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S4.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S40.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S41.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S42.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S43.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S44.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S45.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S46.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S47.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S48.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S49.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S5.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S50.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S51.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S52.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S53.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S54.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S55.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S56.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S57.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S58.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S59.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S6.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S60.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S61.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S62.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S7.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S8.jpg
# Grayscale image saved: PREPROCESSING/segitiga sama sisi Grayscale\S9.jpg

# %%
import cv2
import os

# Directory paths
input_dir = 'PREPROCESSING/segitiga sama sisi Grayscale'
output_dir = 'PREPROCESSING/segitiga sama sisi Binary'

# Memastikan direktori output ada
os.makedirs(output_dir, exist_ok=True)

# Mendapatkan daftar file di direktori input
file_list = os.listdir(input_dir)

# Memproses setiap file gambar
for file_name in file_list:
    # Membaca gambar
    input_path = os.path.join(input_dir, file_name)
    image = cv2.imread(input_path, cv2.IMREAD_GRAYSCALE)  # Membaca langsung sebagai grayscale

    # Memeriksa apakah gambar berhasil dibaca
    if image is None:
        print(f"Failed to read {file_name}")
        continue

    # Mengonversi gambar grayscale menjadi citra biner menggunakan thresholding dengan tipe binary
    _, binary_image = cv2.threshold(image, 10, 255, cv2.THRESH_BINARY)
    
    # Menghilangkan noise menggunakan median blur
    denoised_image = cv2.medianBlur(binary_image, 5)  # Kernel size 5

    # Menyimpan gambar biner di direktori output
    output_path = os.path.join(output_dir, file_name)
    cv2.imwrite(output_path, denoised_image)

    print(f"Processed and saved: {file_name}")

print("Processing complete.")
# Out:
# Processed and saved: S1.jpg
# Processed and saved: S10.jpg
# Processed and saved: S11.jpg
# Processed and saved: S12.jpg
# Processed and saved: S13.jpg
# Processed and saved: S14.jpg
# Processed and saved: S15.jpg
# Processed and saved: S16.jpg
# Processed and saved: S17.jpg
# Processed and saved: S18.jpg
# Processed and saved: S19.jpg
# Processed and saved: S2.jpg
# Processed and saved: S20.jpg
# Processed and saved: S21.jpg
# Processed and saved: S22.jpg
# Processed and saved: S23.jpg
# Processed and saved: S24.jpg
# Processed and saved: S25.jpg
# Processed and saved: S26.jpg
# Processed and saved: S27.jpg
# Processed and saved: S28.jpg
# Processed and saved: S29.jpg
# Processed and saved: S3.jpg
# Processed and saved: S30.jpg
# Processed and saved: S31.jpg
# Processed and saved: S32.jpg
# Processed and saved: S33.jpg
# Processed and saved: S34.jpg
# Processed and saved: S35.jpg
# Processed and saved: S36.jpg
# Processed and saved: S37.jpg
# Processed and saved: S38.jpg
# Processed and saved: S39.jpg
# Processed and saved: S4.jpg
# Processed and saved: S40.jpg
# Processed and saved: S41.jpg
# Processed and saved: S42.jpg
# Processed and saved: S43.jpg
# Processed and saved: S44.jpg
# Processed and saved: S45.jpg
# Processed and saved: S46.jpg
# Processed and saved: S47.jpg
# Processed and saved: S48.jpg
# Processed and saved: S49.jpg
# Processed and saved: S5.jpg
# Processed and saved: S50.jpg
# Processed and saved: S51.jpg
# Processed and saved: S52.jpg
# Processed and saved: S53.jpg
# Processed and saved: S54.jpg
# Processed and saved: S55.jpg
# Processed and saved: S56.jpg
# Processed and saved: S57.jpg
# Processed and saved: S58.jpg
# Processed and saved: S59.jpg
# Processed and saved: S6.jpg
# Processed and saved: S60.jpg
# Processed and saved: S61.jpg
# Processed and saved: S62.jpg
# Processed and saved: S7.jpg
# Processed and saved: S8.jpg
# Processed and saved: S9.jpg
# Processing complete.

# %%
import cv2
import numpy as np
import os

# Path direktori
input_dir = 'PREPROCESSING/segitiga sama sisi Binary'
output_dir = 'PREPROCESSING/segitiga sama sisi Filled'


# Memastikan direktori output ada
os.makedirs(output_dir, exist_ok=True)

# Mendapatkan daftar file di direktori input
file_list = os.listdir(input_dir)

# Memproses setiap file gambar
for file_name in file_list:
    # Membaca gambar
    input_path = os.path.join(input_dir, file_name)
    image = cv2.imread(input_path, cv2.IMREAD_GRAYSCALE)

    # Memeriksa apakah gambar berhasil dibaca
    if image is None:
        print(f"Gagal membaca {file_name}")
        continue

    # Membuat invers dari gambar biner
    inv_image = cv2.bitwise_not(image)

    # Melakukan flood fill dari sudut gambar
    h, w = inv_image.shape[:2]
    mask = np.zeros((h+2, w+2), np.uint8)  # Membuat mask dengan tambahan border
    cv2.floodFill(inv_image, mask, (0, 0), 255)

    # Membuat invers kembali untuk mendapatkan hasil citra yang filled
    filled_image = cv2.bitwise_not(inv_image)

    # Menggabungkan hasil filled dengan citra biner asli
    final_image = cv2.bitwise_or(image, filled_image)
    
    # Proses filling tambahan menggunakan kontur
    ret, thresh = cv2.threshold(final_image, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cv2.drawContours(final_image, contours, -1, (255), thickness=cv2.FILLED)

    # Menyimpan gambar hasil filling di direktori output
    output_path = os.path.join(output_dir, file_name)
    cv2.imwrite(output_path, final_image)

    print(f"Proses filling dan penyimpanan selesai untuk: {file_name}")

print("Proses filling selesai.")
# Out:
# Proses filling dan penyimpanan selesai untuk: S1.jpg
# Proses filling dan penyimpanan selesai untuk: S10.jpg
# Proses filling dan penyimpanan selesai untuk: S11.jpg
# Proses filling dan penyimpanan selesai untuk: S12.jpg
# Proses filling dan penyimpanan selesai untuk: S13.jpg
# Proses filling dan penyimpanan selesai untuk: S14.jpg
# Proses filling dan penyimpanan selesai untuk: S15.jpg
# Proses filling dan penyimpanan selesai untuk: S16.jpg
# Proses filling dan penyimpanan selesai untuk: S17.jpg
# Proses filling dan penyimpanan selesai untuk: S18.jpg
# Proses filling dan penyimpanan selesai untuk: S19.jpg
# Proses filling dan penyimpanan selesai untuk: S2.jpg
# Proses filling dan penyimpanan selesai untuk: S20.jpg
# Proses filling dan penyimpanan selesai untuk: S21.jpg
# Proses filling dan penyimpanan selesai untuk: S22.jpg
# Proses filling dan penyimpanan selesai untuk: S23.jpg
# Proses filling dan penyimpanan selesai untuk: S24.jpg
# Proses filling dan penyimpanan selesai untuk: S25.jpg
# Proses filling dan penyimpanan selesai untuk: S26.jpg
# Proses filling dan penyimpanan selesai untuk: S27.jpg
# Proses filling dan penyimpanan selesai untuk: S28.jpg
# Proses filling dan penyimpanan selesai untuk: S29.jpg
# Proses filling dan penyimpanan selesai untuk: S3.jpg
# Proses filling dan penyimpanan selesai untuk: S30.jpg
# Proses filling dan penyimpanan selesai untuk: S31.jpg
# Proses filling dan penyimpanan selesai untuk: S32.jpg
# Proses filling dan penyimpanan selesai untuk: S33.jpg
# Proses filling dan penyimpanan selesai untuk: S34.jpg
# Proses filling dan penyimpanan selesai untuk: S35.jpg
# Proses filling dan penyimpanan selesai untuk: S36.jpg
# Proses filling dan penyimpanan selesai untuk: S37.jpg
# Proses filling dan penyimpanan selesai untuk: S38.jpg
# Proses filling dan penyimpanan selesai untuk: S39.jpg
# Proses filling dan penyimpanan selesai untuk: S4.jpg
# Proses filling dan penyimpanan selesai untuk: S40.jpg
# Proses filling dan penyimpanan selesai untuk: S41.jpg
# Proses filling dan penyimpanan selesai untuk: S42.jpg
# Proses filling dan penyimpanan selesai untuk: S43.jpg
# Proses filling dan penyimpanan selesai untuk: S44.jpg
# Proses filling dan penyimpanan selesai untuk: S45.jpg
# Proses filling dan penyimpanan selesai untuk: S46.jpg
# Proses filling dan penyimpanan selesai untuk: S47.jpg
# Proses filling dan penyimpanan selesai untuk: S48.jpg
# Proses filling dan penyimpanan selesai untuk: S49.jpg
# Proses filling dan penyimpanan selesai untuk: S5.jpg
# Proses filling dan penyimpanan selesai untuk: S50.jpg
# Proses filling dan penyimpanan selesai untuk: S51.jpg
# Proses filling dan penyimpanan selesai untuk: S52.jpg
# Proses filling dan penyimpanan selesai untuk: S53.jpg
# Proses filling dan penyimpanan selesai untuk: S54.jpg
# Proses filling dan penyimpanan selesai untuk: S55.jpg
# Proses filling dan penyimpanan selesai untuk: S56.jpg
# Proses filling dan penyimpanan selesai untuk: S57.jpg
# Proses filling dan penyimpanan selesai untuk: S58.jpg
# Proses filling dan penyimpanan selesai untuk: S59.jpg
# Proses filling dan penyimpanan selesai untuk: S6.jpg
# Proses filling dan penyimpanan selesai untuk: S60.jpg
# Proses filling dan penyimpanan selesai untuk: S61.jpg
# Proses filling dan penyimpanan selesai untuk: S62.jpg
# Proses filling dan penyimpanan selesai untuk: S7.jpg
# Proses filling dan penyimpanan selesai untuk: S8.jpg
# Proses filling dan penyimpanan selesai untuk: S9.jpg
# Proses filling selesai.

# %%
import cv2
import os
import numpy as np

# Path direktori
input_dir = 'PREPROCESSING/segitiga sama sisi Filled'
output_dir = 'PREPROCESSING/segitiga sama sisi Opening'

# Memastikan direktori output ada
os.makedirs(output_dir, exist_ok=True)

# Mendapatkan daftar file di direktori input
file_list = os.listdir(input_dir)

# Mendefinisikan elemen struktural (kernel) untuk operasi morfologi
kernel = np.ones((5, 5), np.uint8)  # Kernel ukuran 5x5, dapat disesuaikan

# Memproses setiap file gambar
for file_name in file_list:
    # Membaca gambar
    input_path = os.path.join(input_dir, file_name)
    image = cv2.imread(input_path, cv2.IMREAD_GRAYSCALE)

    # Memeriksa apakah gambar berhasil dibaca
    if image is None:
        print(f"Gagal membaca {file_name}")
        continue

    # Melakukan iterasi proses erosi dan dilasi sebanyak 30 kali
    for _ in range(30):
        # Erosi
        eroded_image = cv2.erode(image, kernel, iterations=10)
        # Dilasi
        image = cv2.dilate(eroded_image, kernel, iterations=10)

    # Menyimpan gambar hasil erosi dan dilasi di direktori output
    output_path = os.path.join(output_dir, file_name)
    cv2.imwrite(output_path, image)

    print(f"Proses erosi dan dilasi selesai dan gambar disimpan: {file_name}")

print("Proses erosi dan dilasi selesai untuk semua gambar.")
# Out:
# Proses erosi dan dilasi selesai dan gambar disimpan: S1.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S10.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S11.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S12.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S13.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S14.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S15.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S16.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S17.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S18.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S19.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S2.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S20.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S21.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S22.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S23.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S24.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S25.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S26.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S27.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S28.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S29.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S3.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S30.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S31.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S32.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S33.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S34.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S35.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S36.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S37.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S38.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S39.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S4.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S40.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S41.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S42.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S43.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S44.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S45.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S46.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S47.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S48.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S49.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S5.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S50.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S51.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S52.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S53.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S54.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S55.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S56.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S57.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S58.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S59.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S6.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S60.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S61.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S62.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S7.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S8.jpg
# Proses erosi dan dilasi selesai dan gambar disimpan: S9.jpg
# Proses erosi dan dilasi selesai untuk semua gambar.

# %%
import cv2
import os

# Path direktori
input_dir = 'PREPROCESSING/segitiga sama sisi Opening'
output_dir = 'PREPROCESSING/segitiga sama sisi Edge Detection'
# Memastikan direktori output ada
os.makedirs(output_dir, exist_ok=True)

# Mendapatkan daftar file di direktori input
file_list = os.listdir(input_dir)

# Parameter untuk deteksi tepi Canny
low_threshold = 50
high_threshold = 150

# Memproses setiap file gambar
for file_name in file_list:
    # Membaca gambar
    input_path = os.path.join(input_dir, file_name)
    image = cv2.imread(input_path, cv2.IMREAD_GRAYSCALE)

    # Memeriksa apakah gambar berhasil dibaca
    if image is None:
        print(f"Gagal membaca {file_name}")
        continue

    # Melakukan deteksi tepi menggunakan algoritma Canny
    edges = cv2.Canny(image, low_threshold, high_threshold)

    # Menyimpan gambar hasil deteksi tepi di direktori output
    output_path = os.path.join(output_dir, file_name)
    cv2.imwrite(output_path, edges)

    print(f"Proses deteksi tepi selesai dan gambar disimpan: {file_name}")

print("Proses deteksi tepi selesai untuk semua gambar.")
# Out:
# Proses deteksi tepi selesai dan gambar disimpan: S1.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S10.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S11.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S12.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S13.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S14.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S15.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S16.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S17.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S18.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S19.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S2.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S20.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S21.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S22.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S23.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S24.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S25.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S26.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S27.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S28.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S29.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S3.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S30.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S31.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S32.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S33.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S34.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S35.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S36.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S37.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S38.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S39.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S4.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S40.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S41.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S42.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S43.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S44.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S45.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S46.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S47.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S48.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S49.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S5.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S50.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S51.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S52.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S53.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S54.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S55.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S56.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S57.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S58.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S59.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S6.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S60.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S61.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S62.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S7.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S8.jpg
# Proses deteksi tepi selesai dan gambar disimpan: S9.jpg
# Proses deteksi tepi selesai untuk semua gambar.

# %%
import cv2
import numpy as np
import os

# Path direktori input dan output
input_dir = 'PREPROCESSING/segitiga sama sisi Edge Detection'
output_dir = 'PREPROCESSING/segitiga sama sisi LHT'

# Memastikan direktori output ada
os.makedirs(output_dir, exist_ok=True)

# Ekstensi file gambar yang didukung
supported_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.tif')

# Fungsi untuk melakukan deteksi garis menggunakan Hough Line Transform Probabilistic
def hough_transform(image_path, output_path, line_thickness=3):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    edges = cv2.Canny(img, 50, 150, apertureSize=3)
    
    img_new = edges.copy()
    lines = cv2.HoughLinesP(img_new, rho=1, theta=np.pi/180, threshold=3, minLineLength=0, maxLineGap=15)
    
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line[0]
            cv2.line(img_new, (x1, y1), (x2, y2), (255, 255, 255), line_thickness)
    
    cv2.imwrite(output_path, img_new)

# Looping melalui setiap file gambar dalam direktori input
for filename in os.listdir(input_dir):
    if filename.lower().endswith(supported_extensions):
        image_path = os.path.join(input_dir, filename)
        output_path = os.path.join(output_dir, filename)
        # Lakukan Hough Transform dan simpan hasilnya dengan ketebalan garis 5
        hough_transform(image_path, output_path, line_thickness=100)
        print(f"Proses Hough Transform selesai dan gambar disimpan: {filename}")

print("Proses Hough Transform selesai untuk semua gambar.")
# Out:
# Proses Hough Transform selesai dan gambar disimpan: S1.jpg
# Proses Hough Transform selesai dan gambar disimpan: S10.jpg
# Proses Hough Transform selesai dan gambar disimpan: S11.jpg
# Proses Hough Transform selesai dan gambar disimpan: S12.jpg
# Proses Hough Transform selesai dan gambar disimpan: S13.jpg
# Proses Hough Transform selesai dan gambar disimpan: S14.jpg
# Proses Hough Transform selesai dan gambar disimpan: S15.jpg
# Proses Hough Transform selesai dan gambar disimpan: S16.jpg
# Proses Hough Transform selesai dan gambar disimpan: S17.jpg
# Proses Hough Transform selesai dan gambar disimpan: S18.jpg
# Proses Hough Transform selesai dan gambar disimpan: S19.jpg
# Proses Hough Transform selesai dan gambar disimpan: S2.jpg
# Proses Hough Transform selesai dan gambar disimpan: S20.jpg
# Proses Hough Transform selesai dan gambar disimpan: S21.jpg
# Proses Hough Transform selesai dan gambar disimpan: S22.jpg
# Proses Hough Transform selesai dan gambar disimpan: S23.jpg
# Proses Hough Transform selesai dan gambar disimpan: S24.jpg
# Proses Hough Transform selesai dan gambar disimpan: S25.jpg
# Proses Hough Transform selesai dan gambar disimpan: S26.jpg
# Proses Hough Transform selesai dan gambar disimpan: S27.jpg
# Proses Hough Transform selesai dan gambar disimpan: S28.jpg
# Proses Hough Transform selesai dan gambar disimpan: S29.jpg
# Proses Hough Transform selesai dan gambar disimpan: S3.jpg
# Proses Hough Transform selesai dan gambar disimpan: S30.jpg
# Proses Hough Transform selesai dan gambar disimpan: S31.jpg
# Proses Hough Transform selesai dan gambar disimpan: S32.jpg
# Proses Hough Transform selesai dan gambar disimpan: S33.jpg
# Proses Hough Transform selesai dan gambar disimpan: S34.jpg
# Proses Hough Transform selesai dan gambar disimpan: S35.jpg
# Proses Hough Transform selesai dan gambar disimpan: S36.jpg
# Proses Hough Transform selesai dan gambar disimpan: S37.jpg
# Proses Hough Transform selesai dan gambar disimpan: S38.jpg
# Proses Hough Transform selesai dan gambar disimpan: S39.jpg
# Proses Hough Transform selesai dan gambar disimpan: S4.jpg
# Proses Hough Transform selesai dan gambar disimpan: S40.jpg
# Proses Hough Transform selesai dan gambar disimpan: S41.jpg
# Proses Hough Transform selesai dan gambar disimpan: S42.jpg
# Proses Hough Transform selesai dan gambar disimpan: S43.jpg
# Proses Hough Transform selesai dan gambar disimpan: S44.jpg
# Proses Hough Transform selesai dan gambar disimpan: S45.jpg
# Proses Hough Transform selesai dan gambar disimpan: S46.jpg
# Proses Hough Transform selesai dan gambar disimpan: S47.jpg
# Proses Hough Transform selesai dan gambar disimpan: S48.jpg
# Proses Hough Transform selesai dan gambar disimpan: S49.jpg
# Proses Hough Transform selesai dan gambar disimpan: S5.jpg
# Proses Hough Transform selesai dan gambar disimpan: S50.jpg
# Proses Hough Transform selesai dan gambar disimpan: S51.jpg
# Proses Hough Transform selesai dan gambar disimpan: S52.jpg
# Proses Hough Transform selesai dan gambar disimpan: S53.jpg
# Proses Hough Transform selesai dan gambar disimpan: S54.jpg
# Proses Hough Transform selesai dan gambar disimpan: S55.jpg
# Proses Hough Transform selesai dan gambar disimpan: S56.jpg
# Proses Hough Transform selesai dan gambar disimpan: S57.jpg
# Proses Hough Transform selesai dan gambar disimpan: S58.jpg
# Proses Hough Transform selesai dan gambar disimpan: S59.jpg
# Proses Hough Transform selesai dan gambar disimpan: S6.jpg
# Proses Hough Transform selesai dan gambar disimpan: S60.jpg
# Proses Hough Transform selesai dan gambar disimpan: S61.jpg
# Proses Hough Transform selesai dan gambar disimpan: S62.jpg
# Proses Hough Transform selesai dan gambar disimpan: S7.jpg
# Proses Hough Transform selesai dan gambar disimpan: S8.jpg
# Proses Hough Transform selesai dan gambar disimpan: S9.jpg
# Proses Hough Transform selesai untuk semua gambar.

# %%
import os
import cv2
import numpy as np
import csv

def freeman_chain_code(contour):
    chain_code = []
    for i in range(len(contour)):
        current = contour[i][0]
        next = contour[(i + 1) % len(contour)][0]
        dx = next[0] - current[0]
        dy = next[1] - current[1]
        if dx == 1 and dy == 0:
            chain_code.append(0)
        elif dx == 1 and dy == -1:
            chain_code.append(1)
        elif dx == 0 and dy == -1:
            chain_code.append(2)
        elif dx == -1 and dy == -1:
            chain_code.append(3)
        elif dx == -1 and dy == 0:
            chain_code.append(4)
        elif dx == -1 and dy == 1:
            chain_code.append(5)
        elif dx == 0 and dy == 1:
            chain_code.append(6)
        elif dx == 1 and dy == 1:
            chain_code.append(7)
    return chain_code

def process_images(folder_path, output_csv):
    with open(output_csv, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["Image", "7-Digit Output"])
        
        for filename in os.listdir(folder_path):
            if filename.endswith(('.png', '.jpg', '.jpeg')):
                img_path = os.path.join(folder_path, filename)
                img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                
                # Find contours
                contours, _ = cv2.findContours(img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                
                if contours:
                    # Get the largest contour
                    largest_contour = max(contours, key=cv2.contourArea)
                    
                    # Calculate Freeman Chain Code
                    chain_code = freeman_chain_code(largest_contour)
                    
                    # Get the first 3 digits of the chain code
                    first_three = chain_code[:3] if len(chain_code) >= 3 else chain_code
                    
                    # Append the fixed 4-digit sequence 5-0-1-4
                    output = first_three + [5,0,3]
                    
                    # Write to CSV
                    writer.writerow([filename, output])
                    
                    # Print the output
                    print(f"Image: {filename}")
                    print(f"Output: {output}")
                    print()

# Usage
folder_path = 'PREPROCESSING/segitiga sama sisi LHT'
output_csv = 'KODE RANTAI/S.csv'
process_images(folder_path, output_csv)
# Out:
# Image: S1.jpg
# 7-Digit Output: [6, 7, 1, 5, 0, 3]
#
# Image: S10.jpg
# 7-Digit Output: [5, 0, 7, 5, 0, 3]
#
# Image: S11.jpg
# 7-Digit Output: [7, 6, 7, 5, 0, 3]
#
# Image: S12.jpg
# 7-Digit Output: [3, 5, 1, 5, 0, 3]
#
# Image: S13.jpg
# 7-Digit Output: [7, 5, 6, 5, 0, 3]
#
# Image: S14.jpg
# 7-Digit Output: [5, 6, 7, 5, 0, 3]
#
# Image: S15.jpg
# 7-Digit Output: [6, 7, 5, 5, 0, 3]
#
# Image: S16.jpg
# 7-Digit Output: [5, 4, 5, 5, 0, 3]
#
# Image: S17.jpg
# 7-Digit Output: [6, 7, 1, 5, 0, 3]
#
# Image: S18.jpg
# 7-Digit Output: [5, 7, 7, 5, 0, 3]
#
# Image: S19.jpg
# 7-Digit Output: [5, 4, 0, 5, 0, 3]
#
# Image: S2.jpg
# 7-Digit Output: [6, 5, 3, 5, 0, 3]
#
# Image: S20.jpg
# 7-Digit Output: [7, 7, 6, 5, 0, 3]
#
# Image: S21.jpg
# 7-Digit Output: [5, 3, 5, 5, 0, 3]
#
# Image: S22.jpg
# 7-Digit Output: [5, 7, 5, 5, 0, 3]
#
# Image: S23.jpg
# 7-Digit Output: [7, 6, 5, 5, 0, 3]
#
# Image: S24.jpg
# 7-Digit Output: [5, 4, 0, 5, 0, 3]
#
# Image: S25.jpg
# 7-Digit Output: [6, 7, 1, 5, 0, 3]
#
# Image: S26.jpg
# 7-Digit Output: [7, 5, 4, 5, 0, 3]
#
# Image: S27.jpg
# 7-Digit Output: [7, 0, 7, 5, 0, 3]
#
# Image: S28.jpg
# 7-Digit Output: [6, 7, 4, 5, 0, 3]
#
# Image: S29.jpg
# 7-Digit Output: [6, 5, 3, 5, 0, 3]
#
# Image: S3.jpg
# 7-Digit Output: [5, 0, 7, 5, 0, 3]
#
# Image: S30.jpg
# 7-Digit Output: [5, 0, 7, 5, 0, 3]
#
# Image: S31.jpg
# 7-Digit Output: [5, 4, 5, 5, 0, 3]
#
# Image: S32.jpg
# 7-Digit Output: [5, 4, 3, 5, 0, 3]
#
# Image: S33.jpg
# 7-Digit Output: [5, 6, 5, 5, 0, 3]
#
# Image: S34.jpg
# 7-Digit Output: [5, 7, 5, 5, 0, 3]
#
# Image: S35.jpg
# 7-Digit Output: [6, 5, 3, 5, 0, 3]
#
# Image: S36.jpg
# 7-Digit Output: [0, 5, 4, 5, 0, 3]
#
# Image: S37.jpg
# 7-Digit Output: [6, 7, 1, 5, 0, 3]
#
# Image: S38.jpg
# 7-Digit Output: [5, 7, 5, 5, 0, 3]
#
# Image: S39.jpg
# 7-Digit Output: [6, 5, 3, 5, 0, 3]
#
# Image: S4.jpg
# 7-Digit Output: [6, 7, 1, 5, 0, 3]
#
# Image: S40.jpg
# 7-Digit Output: [7, 5, 4, 5, 0, 3]
#
# Image: S41.jpg
# 7-Digit Output: [7, 6, 7, 5, 0, 3]
#
# Image: S42.jpg
# 7-Digit Output: [6, 7, 6, 5, 0, 3]
#
# Image: S43.jpg
# 7-Digit Output: [7, 5, 6, 5, 0, 3]
#
# Image: S44.jpg
# 7-Digit Output: [6, 7, 6, 5, 0, 3]
#
# Image: S45.jpg
# 7-Digit Output: [7, 0, 7, 5, 0, 3]
#
# Image: S46.jpg
# 7-Digit Output: [7, 5, 6, 5, 0, 3]
#
# Image: S47.jpg
# 7-Digit Output: [6, 7, 6, 5, 0, 3]
#
# Image: S48.jpg
# 7-Digit Output: [6, 5, 3, 5, 0, 3]
#
# Image: S49.jpg
# 7-Digit Output: [6, 7, 1, 5, 0, 3]
#
# Image: S5.jpg
# 7-Digit Output: [5, 0, 7, 5, 0, 3]
#
# Image: S50.jpg
# 7-Digit Output: [7, 6, 7, 5, 0, 3]
#
# Image: S51.jpg
# 7-Digit Output: [7, 6, 1, 5, 0, 3]
#
# Image: S52.jpg
# 7-Digit Output: [7, 1, 7, 5, 0, 3]
#
# Image: S53.jpg
# 7-Digit Output: [5, 4, 6, 5, 0, 3]
#
# Image: S54.jpg
# 7-Digit Output: [5, 0, 7, 5, 0, 3]
#
# Image: S55.jpg
# 7-Digit Output: [7, 6, 7, 5, 0, 3]
#
# Image: S56.jpg
# 7-Digit Output: [6, 5, 3, 5, 0, 3]
#
# Image: S57.jpg
# 7-Digit Output: [5, 0, 7, 5, 0, 3]
#
# Image: S58.jpg
# 7-Digit Output: [6, 7, 6, 5, 0, 3]
#
# Image: S59.jpg
# 7-Digit Output: [5, 4, 6, 5, 0, 3]
#
# Image: S6.jpg
# 7-Digit Output: [5, 4, 3, 5, 0, 3]
#
# Image: S60.jpg
# 7-Digit Output: [6, 5, 3, 5, 0, 3]
#
# Image: S61.jpg
# 7-Digit Output: [7, 5, 6, 5, 0, 3]
#
# Image: S62.jpg
# 7-Digit Output: [6, 7, 1, 5, 0, 3]
#
# Image: S7.jpg
# 7-Digit Output: [7, 5, 6, 5, 0, 3]
#
# Image: S8.jpg
# 7-Digit Output: [7, 0, 7, 5, 0, 3]
#
# Image: S9.jpg
# 7-Digit Output: [5, 6, 2, 5, 0, 3]
