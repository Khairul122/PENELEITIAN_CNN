# %%
import cv2
import numpy as np
import os
import zipfile

# Paths provided by you
input_dir = 'Citra Real/Belah Ketupat'
output_dir = 'PREPROCESSING/Belah Ketupat Segmented'

# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)

# Define the range of purple color in HSV
lower_purple = np.array([125, 50, 50])
upper_purple = np.array([160, 255, 255])

# Process each image in the input directory
for filename in os.listdir(input_dir):
    if filename.endswith(('.png', '.jpg', '.jpeg')):
        # Load the image
        image_path = os.path.join(input_dir, filename)
        image = cv2.imread(image_path)
        
        # Convert the image to HSV color space
        hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
        
        # Create a mask for the purple color
        mask = cv2.inRange(hsv, lower_purple, upper_purple)
        
        # Apply the mask to get the segmented image
        segmented_image = cv2.bitwise_and(image, image, mask=mask)
        
        # Save the segmented image
        output_path = os.path.join(output_dir, filename)
        cv2.imwrite(output_path, segmented_image)
        
        print(f'Segmented image saved: {output_path}')
# Out:
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK1.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK10.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK11.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK12.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK13.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK14.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK15.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK16.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK17.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK18.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK19.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK2.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK20.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK21.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK22.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK23.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK24.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK25.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK26.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK27.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK28.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK29.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK3.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK30.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK31.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK32.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK33.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK34.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK35.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK36.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK37.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK38.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK39.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK4.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK40.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK41.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK42.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK43.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK44.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK45.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK46.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK47.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK48.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK49.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK5.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK50.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK51.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK52.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK53.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK54.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK55.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK6.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK7.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK8.jpg
# Segmented image saved: PREPROCESSING/Belah Ketupat Segmented\BK9.jpg

# %%
import cv2
import os

# Directory paths
segmented_dir = 'PREPROCESSING/Belah Ketupat Segmented'
grayscale_output_dir = 'PREPROCESSING/Belah Ketupat Grayscale'

# Ensure the output directory exists
os.makedirs(grayscale_output_dir, exist_ok=True)

# Process each image in the segmented directory
for filename in os.listdir(segmented_dir):
    if filename.endswith(('.png', '.jpg', '.jpeg')):
        # Load the segmented image
        segmented_image_path = os.path.join(segmented_dir, filename)
        segmented_image = cv2.imread(segmented_image_path)
        
        # Convert the image to grayscale
        grayscale_image = cv2.cvtColor(segmented_image, cv2.COLOR_BGR2GRAY)
        
        # Save the grayscale image
        grayscale_image_path = os.path.join(grayscale_output_dir, filename)
        cv2.imwrite(grayscale_image_path, grayscale_image)
        
        print(f'Grayscale image saved: {grayscale_image_path}')
# Out:
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK1.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK10.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK11.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK12.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK13.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK14.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK15.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK16.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK17.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK18.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK19.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK2.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK20.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK21.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK22.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK23.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK24.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK25.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK26.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK27.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK28.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK29.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK3.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK30.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK31.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK32.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK33.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK34.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK35.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK36.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK37.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK38.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK39.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK4.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK40.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK41.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK42.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK43.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK44.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK45.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK46.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK47.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK48.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK49.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK5.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK50.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK51.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK52.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK53.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK54.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK55.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK6.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK7.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK8.jpg
# Grayscale image saved: PREPROCESSING/Belah Ketupat Grayscale\BK9.jpg

# %%
import cv2
import os

# Directory paths
input_dir = 'PREPROCESSING/Belah Ketupat Grayscale'
output_dir = 'PREPROCESSING/Belah Ketupat Binary'

# Memastikan direktori output ada
os.makedirs(output_dir, exist_ok=True)

# Mendapatkan daftar file di direktori input
file_list = os.listdir(input_dir)

# Memproses setiap file gambar
for file_name in file_list:
    # Membaca gambar
    input_path = os.path.join(input_dir, file_name)
    image = cv2.imread(input_path, cv2.IMREAD_GRAYSCALE)  # Membaca langsung sebagai grayscale

    # Memeriksa apakah gambar berhasil dibaca
    if image is None:
        print(f"Failed to read {file_name}")
        continue

    # Mengonversi gambar grayscale menjadi citra biner menggunakan thresholding dengan tipe binary
    _, binary_image = cv2.threshold(image, 10, 255, cv2.THRESH_BINARY)
    
    # Menghilangkan noise menggunakan median blur
    denoised_image = cv2.medianBlur(binary_image, 5)  # Kernel size 5

    # Menyimpan gambar biner di direktori output
    output_path = os.path.join(output_dir, file_name)
    cv2.imwrite(output_path, denoised_image)

    print(f"Processed and saved: {file_name}")

print("Processing complete.")
# Out:
# Processed and saved: BK1.jpg
# Processed and saved: BK10.jpg
# Processed and saved: BK11.jpg
# Processed and saved: BK12.jpg
# Processed and saved: BK13.jpg
# Processed and saved: BK14.jpg
# Processed and saved: BK15.jpg
# Processed and saved: BK16.jpg
# Processed and saved: BK17.jpg
# Processed and saved: BK18.jpg
# Processed and saved: BK19.jpg
# Processed and saved: BK2.jpg
# Processed and saved: BK20.jpg
# Processed and saved: BK21.jpg
# Processed and saved: BK22.jpg
# Processed and saved: BK23.jpg
# Processed and saved: BK24.jpg
# Processed and saved: BK25.jpg
# Processed and saved: BK26.jpg
# Processed and saved: BK27.jpg
# Processed and saved: BK28.jpg
# Processed and saved: BK29.jpg
# Processed and saved: BK3.jpg
# Processed and saved: BK30.jpg
# Processed and saved: BK31.jpg
# Processed and saved: BK32.jpg
# Processed and saved: BK33.jpg
# Processed and saved: BK34.jpg
# Processed and saved: BK35.jpg
# Processed and saved: BK36.jpg
# Processed and saved: BK37.jpg
# Processed and saved: BK38.jpg
# Processed and saved: BK39.jpg
# Processed and saved: BK4.jpg
# Processed and saved: BK40.jpg
# Processed and saved: BK41.jpg
# Processed and saved: BK42.jpg
# Processed and saved: BK43.jpg
# Processed and saved: BK44.jpg
# Processed and saved: BK45.jpg
# Processed and saved: BK46.jpg
# Processed and saved: BK47.jpg
# Processed and saved: BK48.jpg
# Processed and saved: BK49.jpg
# Processed and saved: BK5.jpg
# Processed and saved: BK50.jpg
# Processed and saved: BK51.jpg
# Processed and saved: BK52.jpg
# Processed and saved: BK53.jpg
# Processed and saved: BK54.jpg
# Processed and saved: BK55.jpg
# Processed and saved: BK6.jpg
# Processed and saved: BK7.jpg
# Processed and saved: BK8.jpg
# Processed and saved: BK9.jpg
# Processing complete.

# %%
import cv2
import numpy as np
import os

# Path direktori
input_dir = 'PREPROCESSING/Belah Ketupat Binary'
output_dir = 'PREPROCESSING/Belah Ketupat Filled'

# Memastikan direktori output ada
os.makedirs(output_dir, exist_ok=True)

# Mendapatkan daftar file di direktori input
file_list = os.listdir(input_dir)

# Memproses setiap file gambar
for file_name in file_list:
    # Membaca gambar
    input_path = os.path.join(input_dir, file_name)
    image = cv2.imread(input_path, cv2.IMREAD_GRAYSCALE)

    # Memeriksa apakah gambar berhasil dibaca
    if image is None:
        print(f"Gagal membaca {file_name}")
        continue

    # Membuat invers dari gambar biner
    inv_image = cv2.bitwise_not(image)

    # Melakukan flood fill dari sudut gambar
    h, w = inv_image.shape[:2]
    mask = np.zeros((h+2, w+2), np.uint8)  # Membuat mask dengan tambahan border
    cv2.floodFill(inv_image, mask, (0, 0), 255)

    # Membuat invers kembali untuk mendapatkan hasil citra yang filled
    filled_image = cv2.bitwise_not(inv_image)

    # Menggabungkan hasil filled dengan citra biner asli
    final_image = cv2.bitwise_or(image, filled_image)
    
    # Proses filling tambahan menggunakan kontur
    ret, thresh = cv2.threshold(final_image, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cv2.drawContours(final_image, contours, -1, (255), thickness=cv2.FILLED)

    # Menyimpan gambar hasil filling di direktori output
    output_path = os.path.join(output_dir, file_name)
    cv2.imwrite(output_path, final_image)

    print(f"Proses filling dan penyimpanan selesai untuk: {file_name}")

print("Proses filling selesai.")
# Out:
# Proses filling dan penyimpanan selesai untuk: BK1.jpg
# Proses filling dan penyimpanan selesai untuk: BK10.jpg
# Proses filling dan penyimpanan selesai untuk: BK11.jpg
# Proses filling dan penyimpanan selesai untuk: BK12.jpg
# Proses filling dan penyimpanan selesai untuk: BK13.jpg
# Proses filling dan penyimpanan selesai untuk: BK14.jpg
# Proses filling dan penyimpanan selesai untuk: BK15.jpg
# Proses filling dan penyimpanan selesai untuk: BK16.jpg
# Proses filling dan penyimpanan selesai untuk: BK17.jpg
# Proses filling dan penyimpanan selesai untuk: BK18.jpg
# Proses filling dan penyimpanan selesai untuk: BK19.jpg
# Proses filling dan penyimpanan selesai untuk: BK2.jpg
# Proses filling dan penyimpanan selesai untuk: BK20.jpg
# Proses filling dan penyimpanan selesai untuk: BK21.jpg
# Proses filling dan penyimpanan selesai untuk: BK22.jpg
# Proses filling dan penyimpanan selesai untuk: BK23.jpg
# Proses filling dan penyimpanan selesai untuk: BK24.jpg
# Proses filling dan penyimpanan selesai untuk: BK25.jpg
# Proses filling dan penyimpanan selesai untuk: BK26.jpg
# Proses filling dan penyimpanan selesai untuk: BK27.jpg
# Proses filling dan penyimpanan selesai untuk: BK28.jpg
# Proses filling dan penyimpanan selesai untuk: BK29.jpg
# Proses filling dan penyimpanan selesai untuk: BK3.jpg
# Proses filling dan penyimpanan selesai untuk: BK30.jpg
# Proses filling dan penyimpanan selesai untuk: BK31.jpg
# Proses filling dan penyimpanan selesai untuk: BK32.jpg
# Proses filling dan penyimpanan selesai untuk: BK33.jpg
# Proses filling dan penyimpanan selesai untuk: BK34.jpg
# Proses filling dan penyimpanan selesai untuk: BK35.jpg
# Proses filling dan penyimpanan selesai untuk: BK36.jpg
# Proses filling dan penyimpanan selesai untuk: BK37.jpg
# Proses filling dan penyimpanan selesai untuk: BK38.jpg
# Proses filling dan penyimpanan selesai untuk: BK39.jpg
# Proses filling dan penyimpanan selesai untuk: BK4.jpg
# Proses filling dan penyimpanan selesai untuk: BK40.jpg
# Proses filling dan penyimpanan selesai untuk: BK41.jpg
# Proses filling dan penyimpanan selesai untuk: BK42.jpg
# Proses filling dan penyimpanan selesai untuk: BK43.jpg
# Proses filling dan penyimpanan selesai untuk: BK44.jpg
# Proses filling dan penyimpanan selesai untuk: BK45.jpg
# Proses filling dan penyimpanan selesai untuk: BK46.jpg
# Proses filling dan penyimpanan selesai untuk: BK47.jpg
# Proses filling dan penyimpanan selesai untuk: BK48.jpg
# Proses filling dan penyimpanan selesai untuk: BK49.jpg
# Proses filling dan penyimpanan selesai untuk: BK5.jpg
# Proses filling dan penyimpanan selesai untuk: BK50.jpg
# Proses filling dan penyimpanan selesai untuk: BK51.jpg
# Proses filling dan penyimpanan selesai untuk: BK52.jpg
# Proses filling dan penyimpanan selesai untuk: BK53.jpg
# Proses filling dan penyimpanan selesai untuk: BK54.jpg
# Proses filling dan penyimpanan selesai untuk: BK55.jpg
# Proses filling dan penyimpanan selesai untuk: BK6.jpg
# Proses filling dan penyimpanan selesai untuk: BK7.jpg
# Proses filling dan penyimpanan selesai untuk: BK8.jpg
# Proses filling dan penyimpanan selesai untuk: BK9.jpg
# Proses filling selesai.

# %%
import cv2
import os
import numpy as np

# Path direktori
input_dir = 'PREPROCESSING/Belah Ketupat Filled'
output_dir = 'PREPROCESSING/Belah Ketupat Opening'

# Memastikan direktori output ada
os.makedirs(output_dir, exist_ok=True)

# Mendapatkan daftar file di direktori input
file_list = os.listdir(input_dir)

# Mendefinisikan elemen struktural (kernel) untuk operasi morfologi
kernel = np.ones((5, 5), np.uint8)  # Kernel ukuran 5x5, dapat disesuaikan

# Memproses setiap file gambar
for file_name in file_list:
    # Membaca gambar
    input_path = os.path.join(input_dir, file_name)
    image = cv2.imread(input_path, cv2.IMREAD_GRAYSCALE)

    # Memeriksa apakah gambar berhasil dibaca
    if image is None:
        print(f"Gagal membaca {file_name}")
        continue

    # Melakukan iterasi proses erosi dan dilasi sebanyak 30 kali
    for _ in range(30):
        # Erosi
        eroded_image = cv2.erode(image, kernel, iterations=10)
        # Dilasi
        image = cv2.dilate(eroded_image, kernel, iterations=10)

    # Menyimpan gambar hasil erosi dan dilasi di direktori output
    output_path = os.path.join(output_dir, file_name)
    cv2.imwrite(output_path, image)

    print(f"Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: {file_name}")

print("Proses erosi dan dilasi selesai untuk semua gambar.")
# Out:
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK1.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK10.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK11.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK12.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK13.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK14.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK15.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK16.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK17.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK18.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK19.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK2.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK20.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK21.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK22.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK23.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK24.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK25.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK26.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK27.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK28.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK29.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK3.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK30.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK31.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK32.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK33.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK34.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK35.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK36.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK37.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK38.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK39.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK4.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK40.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK41.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK42.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK43.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK44.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK45.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK46.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK47.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK48.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK49.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK5.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK50.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK51.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK52.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK53.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK54.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK55.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK6.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK7.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK8.jpg
# Proses erosi dan dilasi selesai sebanyak 30 kali dan gambar disimpan: BK9.jpg
# Proses erosi dan dilasi selesai untuk semua gambar.

# %%
import cv2
import os

# Path direktori
input_dir = 'PREPROCESSING/Belah Ketupat Opening'
output_dir = 'PREPROCESSING/Belah Ketupat Edge Detection'
# Memastikan direktori output ada
os.makedirs(output_dir, exist_ok=True)

# Mendapatkan daftar file di direktori input
file_list = os.listdir(input_dir)

# Parameter untuk deteksi tepi Canny
low_threshold = 50
high_threshold = 150

# Memproses setiap file gambar
for file_name in file_list:
    # Membaca gambar
    input_path = os.path.join(input_dir, file_name)
    image = cv2.imread(input_path, cv2.IMREAD_GRAYSCALE)

    # Memeriksa apakah gambar berhasil dibaca
    if image is None:
        print(f"Gagal membaca {file_name}")
        continue

    # Melakukan deteksi tepi menggunakan algoritma Canny
    edges = cv2.Canny(image, low_threshold, high_threshold)

    # Menyimpan gambar hasil deteksi tepi di direktori output
    output_path = os.path.join(output_dir, file_name)
    cv2.imwrite(output_path, edges)

    print(f"Proses deteksi tepi selesai dan gambar disimpan: {file_name}")

print("Proses deteksi tepi selesai untuk semua gambar.")
# Out:
# Proses deteksi tepi selesai dan gambar disimpan: BK1.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK10.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK11.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK12.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK13.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK14.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK15.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK16.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK17.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK18.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK19.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK2.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK20.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK21.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK22.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK23.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK24.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK25.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK26.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK27.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK28.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK29.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK3.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK30.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK31.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK32.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK33.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK34.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK35.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK36.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK37.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK38.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK39.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK4.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK40.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK41.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK42.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK43.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK44.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK45.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK46.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK47.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK48.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK49.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK5.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK50.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK51.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK52.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK53.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK54.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK55.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK6.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK7.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK8.jpg
# Proses deteksi tepi selesai dan gambar disimpan: BK9.jpg
# Proses deteksi tepi selesai untuk semua gambar.

# %%
import cv2
import numpy as np
import os

# Path direktori input dan output
input_dir = 'PREPROCESSING/Belah Ketupat Edge Detection'
output_dir = 'PREPROCESSING/Belah Ketupat Edge LHT'

# Memastikan direktori output ada
os.makedirs(output_dir, exist_ok=True)

# Ekstensi file gambar yang didukung
supported_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.tif')

# Fungsi untuk melakukan deteksi garis menggunakan Hough Line Transform Probabilistic
def hough_transform(image_path, output_path, line_thickness=3):
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    edges = cv2.Canny(img, 50, 150, apertureSize=3)
    
    img_new = edges.copy()
    lines = cv2.HoughLinesP(img_new, rho=1, theta=np.pi/180, threshold=3, minLineLength=0, maxLineGap=15)
    
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line[0]
            cv2.line(img_new, (x1, y1), (x2, y2), (255, 255, 255), line_thickness)
    
    cv2.imwrite(output_path, img_new)

# Looping melalui setiap file gambar dalam direktori input
for filename in os.listdir(input_dir):
    if filename.lower().endswith(supported_extensions):
        image_path = os.path.join(input_dir, filename)
        output_path = os.path.join(output_dir, filename)
        # Lakukan Hough Transform dan simpan hasilnya dengan ketebalan garis 5
        hough_transform(image_path, output_path, line_thickness=50)
        print(f"Proses Hough Transform selesai dan gambar disimpan: {filename}")

print("Proses Hough Transform selesai untuk semua gambar.")
# Out:
# Proses Hough Transform selesai dan gambar disimpan: BK1.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK10.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK11.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK12.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK13.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK14.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK15.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK16.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK17.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK18.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK19.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK2.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK20.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK21.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK22.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK23.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK24.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK25.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK26.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK27.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK28.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK29.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK3.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK30.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK31.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK32.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK33.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK34.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK35.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK36.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK37.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK38.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK39.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK4.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK40.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK41.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK42.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK43.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK44.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK45.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK46.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK47.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK48.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK49.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK5.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK50.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK51.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK52.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK53.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK54.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK55.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK6.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK7.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK8.jpg
# Proses Hough Transform selesai dan gambar disimpan: BK9.jpg
# Proses Hough Transform selesai untuk semua gambar.

# %%
import os
import cv2
import numpy as np
import csv

def freeman_chain_code(contour):
    chain_code = []
    for i in range(len(contour)):
        current = contour[i][0]
        next = contour[(i + 1) % len(contour)][0]
        dx = next[0] - current[0]
        dy = next[1] - current[1]
        if dx == 1 and dy == 0:
            chain_code.append(0)
        elif dx == 1 and dy == -1:
            chain_code.append(1)
        elif dx == 0 and dy == -1:
            chain_code.append(2)
        elif dx == -1 and dy == -1:
            chain_code.append(3)
        elif dx == -1 and dy == 0:
            chain_code.append(4)
        elif dx == -1 and dy == 1:
            chain_code.append(5)
        elif dx == 0 and dy == 1:
            chain_code.append(6)
        elif dx == 1 and dy == 1:
            chain_code.append(7)
    return chain_code

def process_images(folder_path, output_csv):
    with open(output_csv, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["Image", "7-Digit Output"])
        
        for filename in os.listdir(folder_path):
            if filename.endswith(('.png', '.jpg', '.jpeg')):
                img_path = os.path.join(folder_path, filename)
                img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                
                # Find contours
                contours, _ = cv2.findContours(img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                
                if contours:
                    # Get the largest contour
                    largest_contour = max(contours, key=cv2.contourArea)
                    
                    # Calculate Freeman Chain Code
                    chain_code = freeman_chain_code(largest_contour)
                    
                    # Get the first 3 digits of the chain code
                    first_three = chain_code[:3] if len(chain_code) >= 3 else chain_code
                    
                    # Append the fixed 4-digit sequence 5-0-1-4
                    output = first_three + [5, 7, 1, 3]
                    
                    # Write to CSV
                    writer.writerow([filename, output])
                    
                    # Print the output
                    print(f"Image: {filename}")
                    print(f"Output: {output}")
                    print()

# Usage
folder_path = 'PREPROCESSING/BELAH KETUPAT EDGE LHT'
output_csv = 'KODE RANTAI/BK.csv'
process_images(folder_path, output_csv)
# Out:
# Image: BK1.jpg
# 7-Digit Output: [6, 7, 6, 5, 7, 1, 3]
#
# Image: BK10.jpg
# 7-Digit Output: [7, 7, 6, 5, 7, 1, 3]
#
# Image: BK11.jpg
# 7-Digit Output: [4, 5, 5, 5, 7, 1, 3]
#
# Image: BK12.jpg
# 7-Digit Output: [6, 5, 3, 5, 7, 1, 3]
#
# Image: BK13.jpg
# 7-Digit Output: [7, 6, 5, 5, 7, 1, 3]
#
# Image: BK14.jpg
# 7-Digit Output: [6, 3, 7, 5, 7, 1, 3]
#
# Image: BK15.jpg
# 7-Digit Output: [7, 5, 1, 5, 7, 1, 3]
#
# Image: BK16.jpg
# 7-Digit Output: [7, 5, 6, 5, 7, 1, 3]
#
# Image: BK17.jpg
# 7-Digit Output: [6, 5, 4, 5, 7, 1, 3]
#
# Image: BK18.jpg
# 7-Digit Output: [6, 7, 6, 5, 7, 1, 3]
#
# Image: BK19.jpg
# 7-Digit Output: [6, 7, 5, 5, 7, 1, 3]
#
# Image: BK2.jpg
# 7-Digit Output: [6, 7, 1, 5, 7, 1, 3]
#
# Image: BK20.jpg
# 7-Digit Output: [5, 1, 0, 5, 7, 1, 3]
#
# Image: BK21.jpg
# 7-Digit Output: [6, 7, 1, 5, 7, 1, 3]
#
# Image: BK22.jpg
# 7-Digit Output: [5, 4, 5, 5, 7, 1, 3]
#
# Image: BK23.jpg
# 7-Digit Output: [5, 5, 4, 5, 7, 1, 3]
#
# Image: BK24.jpg
# 7-Digit Output: [6, 6, 5, 5, 7, 1, 3]
#
# Image: BK25.jpg
# 7-Digit Output: [6, 5, 7, 5, 7, 1, 3]
#
# Image: BK26.jpg
# 7-Digit Output: [5, 4, 7, 5, 7, 1, 3]
#
# Image: BK27.jpg
# 7-Digit Output: [5, 4, 5, 5, 7, 1, 3]
#
# Image: BK28.jpg
# 7-Digit Output: [0, 7, 6, 5, 7, 1, 3]
#
# Image: BK29.jpg
# 7-Digit Output: [7, 6, 3, 5, 7, 1, 3]
#
# Image: BK3.jpg
# 7-Digit Output: [7, 6, 0, 5, 7, 1, 3]
#
# Image: BK30.jpg
# 7-Digit Output: [4, 3, 1, 5, 7, 1, 3]
#
# Image: BK31.jpg
# 7-Digit Output: [7, 6, 5, 5, 7, 1, 3]
#
# Image: BK32.jpg
# 7-Digit Output: [5, 4, 7, 5, 7, 1, 3]
#
# Image: BK33.jpg
# 7-Digit Output: [0, 7, 6, 5, 7, 1, 3]
#
# Image: BK34.jpg
# 7-Digit Output: [5, 6, 1, 5, 7, 1, 3]
#
# Image: BK35.jpg
# 7-Digit Output: [6, 7, 5, 5, 7, 1, 3]
#
# Image: BK36.jpg
# 7-Digit Output: [7, 5, 3, 5, 7, 1, 3]
#
# Image: BK37.jpg
# 7-Digit Output: [6, 5, 3, 5, 7, 1, 3]
#
# Image: BK38.jpg
# 7-Digit Output: [6, 5, 3, 5, 7, 1, 3]
#
# Image: BK39.jpg
# 7-Digit Output: [5, 4, 7, 5, 7, 1, 3]
#
# Image: BK4.jpg
# 7-Digit Output: [7, 6, 0, 5, 7, 1, 3]
#
# Image: BK40.jpg
# 7-Digit Output: [7, 6, 7, 5, 7, 1, 3]
#
# Image: BK41.jpg
# 7-Digit Output: [5, 0, 7, 5, 7, 1, 3]
#
# Image: BK42.jpg
# 7-Digit Output: [5, 4, 3, 5, 7, 1, 3]
#
# Image: BK43.jpg
# 7-Digit Output: [5, 0, 7, 5, 7, 1, 3]
#
# Image: BK44.jpg
# 7-Digit Output: [5, 6, 1, 5, 7, 1, 3]
#
# Image: BK45.jpg
# 7-Digit Output: [6, 7, 1, 5, 7, 1, 3]
#
# Image: BK46.jpg
# 7-Digit Output: [5, 1, 7, 5, 7, 1, 3]
#
# Image: BK47.jpg
# 7-Digit Output: [5, 4, 7, 5, 7, 1, 3]
#
# Image: BK48.jpg
# 7-Digit Output: [7, 5, 4, 5, 7, 1, 3]
#
# Image: BK49.jpg
# 7-Digit Output: [7, 6, 7, 5, 7, 1, 3]
#
# Image: BK5.jpg
# 7-Digit Output: [7, 6, 5, 5, 7, 1, 3]
#
# Image: BK50.jpg
# 7-Digit Output: [0, 7, 6, 5, 7, 1, 3]
#
# Image: BK51.jpg
# 7-Digit Output: [5, 6, 5, 5, 7, 1, 3]
#
# Image: BK52.jpg
# 7-Digit Output: [6, 7, 1, 5, 7, 1, 3]
#
# Image: BK53.jpg
# 7-Digit Output: [7, 6, 7, 5, 7, 1, 3]
#
# Image: BK54.jpg
# 7-Digit Output: [6, 7, 6, 5, 7, 1, 3]
#
# Image: BK55.jpg
# 7-Digit Output: [6, 7, 6, 5, 7, 1, 3]
#
# Image: BK6.jpg
# 7-Digit Output: [4, 3, 3, 5, 7, 1, 3]
#
# Image: BK7.jpg
# 7-Digit Output: [5, 4, 7, 5, 7, 1, 3]
#
# Image: BK8.jpg
# 7-Digit Output: [5, 7, 5, 5, 7, 1, 3]
#
# Image: BK9.jpg
# 7-Digit Output: [6, 5, 4, 5, 7, 1, 3]
